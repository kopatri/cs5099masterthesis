# %% [markdown]
# # CORD-19 Software Counting
# This jupyter notebook is designated to count software mentions based on the CORD19 dataset from:
# https://datadryad.org/stash/dataset/doi:10.5061/dryad.vmcvdncs0

# %% [markdown]
# First, relevant packages must be imported to the Notebook.

# %%
import numpy as np
import pandas as pd
import csv
import ast
import collections
import matplotlib.pyplot as plt
import Levenshtein as lev
from fuzzywuzzy import fuzz

# %% [markdown]
# Get the data and save it to a variable.

# %%
CORD19_CSV = pd.read_csv('../data/cord-19/CORD19_software_mentions.csv' , converters={'software': lambda x: x[1:-1].split(',')})

# %% [markdown]
# Show the head of the dataset to inspect all columns and obtain a broad overview.

# %%
CORD19_CSV.head(20)
# Out:
#                                     paper_id  \
# 0   00006903b396d50cc0037fed39916d57d50ee801
# 1   0000fcce604204b1b9d876dc073eb529eb5ce305
# 2   000122a9a774ec76fa35ec0c0f6734e7e8d0c541
# 3   0001418189999fea7f7cbe3e82703d71c85a6fe5
# 4   00033d5a12240a8684cfe943954132b43434cf48
# 5   00035ac98d8bc38fbca02a1cc957f55141af67c0
# 6   00039b94e6cb7609ecbddee1755314bcfeb77faa
# 7   0004456994f6c1d5db7327990386d33c01cff32a
# 8   00073cb65dd2596249230fab8b15a71c4a135895
# 9   0007f972812bb45abbe5b0edf8db5359d49c23eb
# 10  0008c57de475138d903f2cca7003cf1e1ad93cf4
# 11  000a0fc8bbef80410199e690191dc3076a290117
# 12  000d3b13a645c10826aaf2cf0bb0dc18b9580ac2
# 13  000e43590fdd2e011cfadaa14e6c14f318d11bbb
# 14  000eec3f1e93c3792454ac59415c928ce3a6b4ad
# 15  000f207d1ee7f674091bf5867561c329928990e6
# 16  00102e5960addaa80152672003969e2dffe0d22b
# 17  001085074ee7d900b7be7a43598018650a1c310f
# 18  0010f32ac43ca5864983343672936b536431ae90
# 19  001139d307c2329d2b34a25d5b35ba84c6deb382
#
#                                  doi  \
# 0                                NaN
# 1         10.1016/j.regg.2021.01.002
# 2          10.1016/j.rec.2020.08.002
# 3       10.1016/j.vetmic.2006.11.026
# 4                  10.3390/v12080849
# 5          10.3389/fpsyt.2020.559701
# 6   10.1111/j.1365-2249.2004.02415.x
# 7             10.1186/1471-2334-10-8
# 8                     10.1086/605034
# 9         10.1186/s42234-020-00057-1
# 10        10.1140/epje/i2018-11644-5
# 11         10.1186/s13071-020-3918-5
# 12        10.1007/s00548-020-00686-3
# 13         10.1186/s12910-015-0002-3
# 14      10.1016/j.reaurg.2004.02.009
# 15          10.1177/2324709620957778
# 16                 10.1111/jdv.16974
# 17         10.1007/s13341-016-0615-2
# 18                               NaN
# 19         10.1007/s11623-020-1314-0
#
#                                                 title                source_x  \
# 0   Urban green space and happiness in developed c...                   ArXiv
# 1   La Geriatría de Enlace con residencias en la é...           Elsevier; PMC
# 2   Impact of COVID-19 on ST-segment elevation myo...  Elsevier; Medline; PMC
# 3   Absence of surface expression of feline infect...  Elsevier; Medline; PMC
# 4   Detection of Severe Acute Respiratory Syndrome...            Medline; PMC
# 5   The Psychological Pressures of Breast Cancer P...            Medline; PMC
# 6   Plasma inflammatory cytokines and chemokines i...            Medline; PMC
# 7   Seasonal influenza risk in hospital healthcare...                     PMC
# 8   Risk Parameters of Fulminant Acute Respiratory...            Medline; PMC
# 9   The role of nicotinic receptors in SARS-CoV-2 ...            Medline; PMC
# 10  The effect of gramicidin inclusions on the loc...            Medline; PMC
# 11  PfSWIB, a potential chromatin regulator for va...                     PMC
# 12                                      Standort-Info                     PMC
# 13  Innovations in research ethics governance in h...                     PMC
# 14       Pneumonie virale sévère de l'immunocompétent  Elsevier; Medline; PMC
# 15  A Case of Extracorporeal Membrane Oxygenation ...            Medline; PMC
# 16  Why are chilblains underreported in Nordic cou...            Medline; PMC
# 17  Retour d’expérience des attentats du 13 novemb...                     PMC
# 18  Respiratory Distress Detection from Telephone ...                   ArXiv
# 19     Datensicherheit von Corona-Apps nach der DSGVO                     PMC
#
#       license publish_time                              journal  \
# 0       arxiv   2021-01-04                                  NaN
# 1   els-covid   2021-01-13             Rev Esp Geriatr Gerontol
# 2       no-cc   2020-09-08            Rev Esp Cardiol (Engl Ed)
# 3       no-cc   2007-03-31                        Vet Microbiol
# 4       cc-by   2020-08-04                              Viruses
# 5       cc-by   2020-12-15                     Front Psychiatry
# 6   bronze-oa   2004-04-01   Clinical & Experimental Immunology
# 7       cc-by   2010-01-12                       BMC Infect Dis
# 8       no-cc   2009-08-01                         J Infect Dis
# 9       cc-by   2020-10-28                      Bioelectron Med
# 10      no-cc   2018-03-28             Eur Phys J E Soft Matter
# 11      cc-by   2020-02-04                      Parasit Vectors
# 12      no-cc   2020-11-20                             Standort
# 13      cc-by   2015-02-26                       BMC Med Ethics
# 14  els-covid   2004-05-31                          Réanimation
# 15   cc-by-nc   2020-09-10  J Investig Med High Impact Case Rep
# 16      no-cc   2020-10-22         J Eur Acad Dermatol Venereol
# 17      no-cc   2016-02-10                                  NaN
# 18      arxiv   2020-11-15                                  NaN
# 19      no-cc   2020-07-27                Datenschutz Datensich
#
#                                                   url  \
# 0              https://arxiv.org/pdf/2101.00807v1.pdf
# 1   https://api.elsevier.com/content/article/pii/S...
# 2   https://api.elsevier.com/content/article/pii/S...
# 3   https://www.sciencedirect.com/science/article/...
# 4   https://www.ncbi.nlm.nih.gov/pubmed/32759673/;...
# 5   https://doi.org/10.3389/fpsyt.2020.559701; htt...
# 6   https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 7   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 8   https://doi.org/10.1086/605034; https://www.nc...
# 9   https://www.ncbi.nlm.nih.gov/pubmed/33292872/;...
# 10  https://www.ncbi.nlm.nih.gov/pubmed/29582214/;...
# 11  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 12  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 13  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 14  https://doi.org/10.1016/j.reaurg.2004.02.009; ...
# 15  https://www.ncbi.nlm.nih.gov/pubmed/32911986/;...
# 16  https://doi.org/10.1111/jdv.16974; https://www...
# 17  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 18             https://arxiv.org/pdf/2011.09270v1.pdf
# 19  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                                              software
# 0                              ['Google Street View']
# 1                                            ['SEGG']
# 2                               ['STATA',  'IAMCEST']
# 3                                            ['SPSS']
# 4                  ['R',  'MassARRAY Typer Analyzer']
# 5                      ['Wechat',  'SPSS Statistics']
# 6   ['Statistical Package for Social Sciences (SPS...
# 7                   ['STATA',  'STATA',  'Statacorp']
# 8                                   ['SPSS',  'SPSS']
# 9   ['geNorm',  'GraphPad Prism',  'GraphPad',  'C...
# 10                                          ['GramA']
# 11  ['R package edgeR',  'R package edgeR',  'R pa...
# 12                           ['MORO Praxis',  'MORO']
# 13                                           ['R2HC']
# 14                                      ['Singapour']
# 15                                         ['PRESET']
# 16                       ['Google Trends (GT',  'GT']
# 17                             ['SINUS',  'VICTIMES']
# 18  ['Spirocall',  'LIBSVM',  'MATLAB voicebox',  ...
# 19  ['DP',  'DP',  'DSGVO',  'iOS',  'DSGVO',  'PE...

# %% [markdown]
# The dataset contains nine different columns.
# Thusly, the next lines of this notebook explores the column "software".
# Therefore, the column software will be saved to a object.

# %%
software = CORD19_CSV.software

# %%
software
# Out:
# 0                    ['Google Street View']
# 1                                  ['SEGG']
# 2                     ['STATA',  'IAMCEST']
# 3                                  ['SPSS']
# 4        ['R',  'MassARRAY Typer Analyzer']
#                         ...
# 77443                          ['UpToDate']
# 77444                   ['SALib',  'Panda']
# 77445                ['Prism',  'GraphPad']
# 77446    ['R package circular',  'R',  'R']
# 77447       ['GRAM',  'R studio',  'Stata']
# Name: software, Length: 77448, dtype: object

# %%
len_software_multiple_entries = len(software)
len_software_multiple_entries
# Out:
# 77448

# %% [markdown]
# The software object contains 77448 rows. In each row, there are software entries. Some rows contain more than one software entry. For instance, row two and four have each two entries. As a result, the object needs to be transformed to an object which contains soley one software entry per row.

# %%
software = software.explode(ignore_index = True)

# %% [markdown]
# Remove the brackets around the software mentions.

# %%
software = software.str.replace('\'', '')

# %% [markdown]
# Control the software object and inspect if each row contains only one entry.

# %%
software
# Out:
# 0         Google Street View
# 1                       SEGG
# 2                      STATA
# 3                    IAMCEST
# 4                       SPSS
#                  ...
# 558787                     R
# 558788                     R
# 558789                  GRAM
# 558790              R studio
# 558791                 Stata
# Name: software, Length: 558792, dtype: object

# %%
len_software_single_entries = len(software)
len_software_single_entries
# Out:
# 558792

# %% [markdown]
# Now, the object contains solely one entry per row and has the length of 558792.

# %%
average_entries_per_row = len_software_single_entries/len_software_multiple_entries
average_entries_per_row
# Out:
# 7.215060427641773

# %% [markdown]
# Due to the alignment of the software object, it can be obtained that the dataset contains on average 7.2 software entries per row. Furthermore, the value_counts function will be user to minimise the amount of rows by checking identical duplicates.

# %%
software.value_counts(dropna=False)
# Out:
#  R                            8389
#  SPSS                         4738
# SPSS                          4472
#  BLAST                        3166
#  Excel                        2666
#                               ...
# "R package  graphics"            1
#  SnpEff (SNP Effects)            1
#  Gatan Microscopy Suite 37       1
#  MyoMaster                       1
# VULNERABLE                       1
# Name: software, Length: 120264, dtype: int64

# %% [markdown]
# The function value_counts reduced the amount of rows to 120279. Nevertheless, the dtype counts same software mentions as distinct. For instance, "SPSS" is listed twice with two varied numbers. For this, the datatype will be converted to a dictionary to check for possible empty spaces.

# %%
software_dict = software.to_dict()
software_dict
# Out:
# {0: 'Google Street View',
#  1: 'SEGG',
#  2: 'STATA',
#  3: ' IAMCEST',
#  4: 'SPSS',
#  5: 'R',
#  6: ' MassARRAY Typer Analyzer',
#  7: 'Wechat',
#  8: ' SPSS Statistics',
#  9: 'Statistical Package for Social Sciences (SPSS)',
#  10: ' BD CBA',
#  11: 'STATA',
#  12: ' STATA',
#  13: ' Statacorp',
#  14: 'SPSS',
#  15: ' SPSS',
#  16: 'geNorm',
#  17: ' GraphPad Prism',
#  18: ' GraphPad',
#  19: ' Cellranger',
#  20: ' R',
#  21: ' Seurat',
#  22: ' ggplot2',
#  23: ' LinRegPCR',
#  24: 'GramA',
#  25: 'R package edgeR',
#  26: ' R package edgeR',
#  27: ' R package edgeR',
#  28: ' STAR',
#  29: ' FastQC',
#  30: ' R package ALDEx2',
#  31: ' ImageJ',
#  32: ' PfAlbas',
#  33: ' SAM',
#  34: 'MORO Praxis',
#  35: ' MORO',
#  36: 'R2HC',
#  37: 'Singapour',
#  38: 'PRESET',
#  39: 'Google Trends (GT',
#  40: ' GT',
#  41: 'SINUS',
#  42: ' VICTIMES',
#  43: 'Spirocall',
#  44: ' LIBSVM',
#  45: ' MATLAB voicebox',
#  46: ' openS',
#  47: ' MILE',
#  48: 'DP',
#  49: ' DP',
#  50: ' DSGVO',
#  51: ' iOS',
#  52: ' DSGVO',
#  53: ' PEPP',
#  54: ' PT',
#  55: ' DP',
#  56: ' 3T',
#  57: 'REDCapbased',
#  58: ' REDCap',
#  59: ' Research Electronic Data Capture',
#  60: ' R',
#  61: 'DDCNN',
#  62: ' AR',
#  63: ' INCART',
#  64: ' CLSM',
#  65: ' MIT',
#  66: ' BIH',
#  67: ' SUP',
#  68: ' INCART',
#  69: ' CLSM',
#  70: ' CLSM',
#  71: ' INCART',
#  72: ' Adam',
#  73: ' SOMTE',
#  74: ' SMOTE',
#  75: ' SMOTE',
#  76: ' CLSM',
#  77: ' INCART',
#  78: ' CLSM',
#  79: ' CLSM',
#  80: ' INCART',
#  81: ' CLSM',
#  82: ' CLSM',
#  83: 'SPSS',
#  84: ' SPSS',
#  85: ' CT Scan',
#  86: 'NCCS',
#  87: 'GraphPad Prism',
#  88: ' GraphPad',
#  89: ' Zen Zeiss',
#  90: ' FlowJo',
#  91: ' Zen Zeiss',
#  92: 'MCT',
#  93: 'Ribo',
#  94: ' Ribo',
#  95: ' Ribo',
#  96: ' Seq',
#  97: 'Random Forest',
#  98: ' LOOCV',
#  99: ' branch',
#  100: ' HDP',
#  101: ' Mbranch',
#  102: 'LAMP',
#  103: ' NEAR',
#  104: ' LAMP',
#  105: ' NEAR',
#  106: 'GISAID',
#  107: ' MAFFT',
#  108: ' Bioedit',
#  109: ' SwissModel',
#  110: ' HHpred',
#  111: ' MEME',
#  112: ' Mutant2',
#  113: ' TMHMM',
#  114: ' Protter',
#  115: ' SwissModel',
#  116: ' HHPred',
#  117: ' Jpred',
#  118: ' IQ',
#  119: ' TREE',
#  120: ' IQ',
#  121: ' TREE',
#  122: ' ACS',
#  123: ' GISAID',
#  124: ' Py',
#  125: ' MOL',
#  126: ' Jpred',
#  127: ' TMHMM',
#  128: ' Protter',
#  129: ' Tasser',
#  130: ' Tasser',
#  131: ' Adaptive Evolution Server',
#  132: 'DECNEO',
#  133: ' DECNEO',
#  134: ' numpy',
#  135: ' scipy',
#  136: ' pandas',
#  137: ' scikit',
#  138: ' learn',
#  139: ' matplotlib',
#  140: ' PyIOmica',
#  141: ' Metascape',
#  142: ' PyPI',
#  143: ' DECNEO',
#  144: ' DECNEO',
#  145: ' CellRanger',
#  146: ' Metascape',
#  147: ' PanglaoDB',
#  148: ' R',
#  149: ' gravity',
#  150: ' Metascape',
#  151: ' DECNEO',
#  152: ' Alona',
#  153: ' DECNEO',
#  154: ' CellRanger',
#  155: ' DECNEO',
#  156: ' DECNEO',
#  157: ' DECNEO',
#  158: ' Metascape',
#  159: ' DECNEO (DEndrogram of Co - expression with Evolutionary Conservation and Network Enrichment Ordering)',
#  160: ' DECNEO',
#  161: ' Snowmass',
#  162: ' Metascape',
#  163: 'SPSS',
#  164: 'Ensembl',
#  165: ' BioMart',
#  166: ' REVIGO',
#  167: ' Cytoscape',
#  168: ' Cytoscape',
#  169: ' ClueGO',
#  170: ' ReviGO',
#  171: ' VetScan',
#  172: ' ReviGO',
#  173: ' Cytoscape',
#  174: ' REVIGO',
#  175: ' SimRel',
#  176: ' Cytoscape',
#  177: ' ClueGO',
#  178: 'GraphPad prism',
#  179: ' GraphPad prism',
#  180: 'QSR NVivo',
#  181: ' Engage',
#  182: 'SPSS',
#  183: ' R',
#  184: ' R Foundation for Statistical',
#  185: 'SAS',
#  186: ' STATA',
#  187: ' CONEVAL',
#  188: 'Curevac',
#  189: 'Stata MP15',
#  190: ' PROLISA',
#  191: 'Blood Sugar Lounge',
#  192: 'COVIDX',
#  193: ' Net',
#  194: ' Inception',
#  195: ' InceptionV3',
#  196: ' Xception',
#  197: ' MobileNetV2',
#  198: ' XceptionNet',
#  199: ' GitHub',
#  200: 'Google Scholar',
#  201: 'PAR',
#  202: ' PAR',
#  203: ' ENT',
#  204: ' QoL',
#  205: ' PAR',
#  206: ' QoL',
#  207: ' PAR',
#  208: ' ENT',
#  209: ' QoL',
#  210: 'AUDiaL',
#  211: ' Semantic Annotator for Inkscape (SAI)',
#  212: ' AUDiaL',
#  213: ' AUDiaL',
#  214: ' AUDiaL',
#  215: ' AUDiaL',
#  216: ' AUDiaL',
#  217: ' AUDiaL',
#  218: ' AUDiaL',
#  219: ' AUDiaL',
#  220: ' AUDiaL',
#  221: ' AUDiaL',
#  222: ' AUDiaL',
#  223: ' AUDiaL',
#  224: ' AUDiaL',
#  225: ' AUDiaL',
#  226: ' AUDiaL',
#  227: ' AUDiaL (Accessible Universal Diagrams through Language)',
#  228: ' AUDiaL',
#  229: ' AUDiaL',
#  230: ' AUDiaL',
#  231: ' AUDiaL',
#  232: ' AUDiaL',
#  233: ' AUDiaL',
#  234: ' AUDiaL (Accessible Universal Diagrams through Language)',
#  235: ' AUDiaL',
#  236: ' AUDiaL',
#  237: ' AUDiaL',
#  238: ' AUDiaL',
#  239: 'TCGA2STAT',
#  240: ' SSL',
#  241: ' netDx',
#  242: ' iDRW',
#  243: ' iDRW',
#  244: ' netDx',
#  245: ' iDRW',
#  246: ' netDx',
#  247: ' iDRW',
#  248: ' OMICSBind',
#  249: ' netDx',
#  250: ' iDRW',
#  251: ' iDRW',
#  252: ' netDx',
#  253: ' iDRW',
#  254: ' netDx',
#  255: ' iDRW',
#  256: ' iDRW',
#  257: ' ToppGenet',
#  258: ' OMICSBind',
#  259: ' TCGA2STAT',
#  260: ' iDRW',
#  261: ' netDx',
#  262: ' SSL Omics',
#  263: ' SSL Omics',
#  264: ' iDRW',
#  265: ' netDx',
#  266: ' SSL',
#  267: 'Graph',
#  268: ' - Pad Prizm',
#  269: ' Graph',
#  270: ' - Pad',
#  271: ' GenScript',
#  272: 'SPSS Statistics',
#  273: ' NEWS',
#  274: ' Original',
#  275: 'XPRIZE',
#  276: ' XPRIZE',
#  277: ' CODATA',
#  278: ' XPRIZE',
#  279: ' XPRIZE Pandemic',
#  280: ' XPRIZE',
#  281: ' Idea Builder',
#  282: ' Open COVID Pledge',
#  283: ' CODATA',
#  284: ' OSMS',
#  285: ' XPRIZE',
#  286: ' CODATA',
#  287: ' ACCORD',
#  288: ' INGSA',
#  289: ' XPRIZE',
#  290: ' Uber',
#  291: ' CODATA',
#  292: ' COVID Commons',
#  293: ' RESOLVE',
#  294: ' OSMS',
#  295: ' XPRIZE',
#  296: ' XPRIZE',
#  297: 'GraphPad Prism',
#  298: ' GraphPad',
#  299: 'LNRE',
#  300: ' LNRE',
#  301: ' LNRE',
#  302: 'TE',
#  303: ' Realpolitik',
#  304: 'Google Scholar',
#  305: 'SPSS Statistics',
#  306: ' Prism',
#  307: ' GraphPad',
#  308: ' RECOVERY',
#  309: 'Dantec',
#  310: ' Dynam',
#  311: ' icStudio',
#  312: 'QuantaSoft',
#  313: 'SPAR',
#  314: ' SPAR',
#  315: ' JEE',
#  316: ' JEE',
#  317: 'Cochrane',
#  318: ' Review Manager',
#  319: ' Cochrane',
#  320: ' Review Manager',
#  321: ' PRISMA',
#  322: 'Vital',
#  323: ' Vital',
#  324: ' MODBUS',
#  325: ' XAI',
#  326: ' Vital',
#  327: ' Vital',
#  328: ' Vital',
#  329: ' SWAMP',
#  330: ' Vital',
#  331: ' Cenote',
#  332: 'SPSS',
#  333: ' SPSS',
#  334: 'SPSS Statistics',
#  335: ' Oracle',
#  336: 'SPSS Statistics',
#  337: ' ANOSIM',
#  338: ' OptiClust',
#  339: ' CANOCO',
#  340: ' Analysis of Similarity (ANOSIM)',
#  341: ' Gen',
#  342: ' AlEx',
#  343: ' anosim',
#  344: ' mothur',
#  345: ' mothur',
#  346: ' unifrac',
#  347: ' mothur',
#  348: ' LEfSe',
#  349: 'PSORT',
#  350: ' PSORT',
#  351: 'SPSS',
#  352: 'ETAT',
#  353: ' ETAT',
#  354: ' PRISM',
#  355: 'FV',
#  356: 'Forrest',
#  357: 'Stata',
#  358: 'Mendeley Desktop',
#  359: 'STATA',
#  360: ' excel',
#  361: 'endnote',
#  362: ' Scopus',
#  363: 'ScPL',
#  364: ' DGGRL',
#  365: ' ANOSIM',
#  366: ' R',
#  367: ' Excel',
#  368: ' SPSS',
#  369: ' ECVIM',
#  370: ' Genome Analysis ToolKit',
#  371: ' SUPERSAT',
#  372: ' ACVIM',
#  373: ' Xstrain',
#  374: ' Burdick Holter Analysis',
#  375: ' Prism7',
#  376: ' ImmTT4',
#  377: ' CataT4',
#  378: 'GraphPad Prism',
#  379: ' SigmaPlot',
#  380: ' Systat',
#  381: 'NSIP',
#  382: 'ProMED',
#  383: ' mail',
#  384: ' FluNet',
#  385: ' FluID',
#  386: ' DOCS',
#  387: ' GPHIN',
#  388: ' GOARN',
#  389: ' GOARN',
#  390: ' GOARN',
#  391: ' ProMED',
#  392: ' mail',
#  393: 'GraphPad Prism',
#  394: ' GraphPad Prism',
#  395: 'GRECCAR2',
#  396: ' STENT',
#  397: ' IDEAL',
#  398: ' GRECCAR',
#  399: ' GRECCAR2',
#  400: ' GRECCAR',
#  401: 'SmartPLS',
#  402: ' KakaoTalk',
#  403: ' SPSS Statistics',
#  404: ' Smart PLS',
#  405: ' Google Drive',
#  406: ' KakaoTalk',
#  407: 'ImageJ',
#  408: ' SPSS',
#  409: ' qBase',
#  410: ' Image J',
#  411: ' geNorm',
#  412: ' UFibro',
#  413: ' ImageJ',
#  414: 'REDCap',
#  415: ' Research Electronic Data Capture (REDCap)',
#  416: ' REDCap',
#  417: 'Navigator Network NET',
#  418: ' NTS',
#  419: ' NET',
#  420: ' Tensorflow',
#  421: ' DeepLift',
#  422: ' DeepLift',
#  423: 'DANN',
#  424: ' SANN',
#  425: 'R',
#  426: ' RStudio',
#  427: 'R',
#  428: ' R',
#  429: ' WhatsApp TM',
#  430: ' REDCap',
#  431: 'mfold',
#  432: ' mfold',
#  433: ' mfold',
#  434: ' mfold',
#  435: ' mfold',
#  436: 'Open',
#  437: ' Open Science',
#  438: ' Open',
#  439: 'CO',
#  440: ' CIN',
#  441: 'CORD',
#  442: ' gensim',
#  443: ' VOSviewer',
#  444: ' VOSviewer',
#  445: ' ScispaCy',
#  446: ' VOSviewer',
#  447: ' Altmetric',
#  448: ' Dimensions',
#  449: ' WoS',
#  450: ' strict',
#  451: ' Altmetric',
#  452: ' Dimensions',
#  453: ' Altmetric',
#  454: ' Altmetric',
#  455: ' Altmetric',
#  456: ' PMC',
#  457: ' VOSviewer',
#  458: ' Altmetric',
#  459: 'Excel',
#  460: ' EPI',
#  461: ' INFO',
#  462: ' SAS',
#  463: ' SAS',
#  464: 'SPSS',
#  465: ' SPSS',
#  466: 'Flow',
#  467: ' Stata',
#  468: ' GraphPad Prism',
#  469: 'Review Manager',
#  470: 'Adam',
#  471: ' fastText',
#  472: ' ELMO',
#  473: 'Skype',
#  474: ' Facetime',
#  475: 'MESH',
#  476: ' MEDLINE',
#  477: ' KAON',
#  478: ' KAON',
#  479: ' Headache',
#  480: ' KAON',
#  481: ' KAON',
#  482: ' KAON',
#  483: ' KAON',
#  484: ' MEDLINE',
#  485: ' MEDLINE',
#  486: ' KAON',
#  487: 'GPC',
#  488: ' GPC',
#  489: 'Matlab',
#  490: ' Matlab',
#  491: 'NL Actief',
#  492: 'Excel',
#  493: ' Excel',
#  494: 'Optimas',
#  495: ' Optimast',
#  496: ' SPSS',
#  497: ' SPSS',
#  498: ' Excel',
#  499: 'VMD',
#  500: ' GNUPLOT',
#  501: ' ProDy',
#  502: 'SPSS',
#  503: ' CONSORT',
#  504: 'FILEMAKER PRO',
#  505: ' ANALYSIS',
#  506: ' Stata',
#  507: ' Biacore',
#  508: 'MEGA',
#  509: 'eRisk',
#  510: ' Reddit',
#  511: ' eRisk',
#  512: ' Linguistic Inquiry and Word Count LIWC',
#  513: ' LIWC',
#  514: ' Reddit',
#  515: ' LIWC',
#  516: ' Early Risk Prediction on Internet (eRisk) Linguistics and Clinical Psychology (CLPsych)',
#  517: ' eRisk',
#  518: 'Worldometers',
#  519: 'SmartPLS',
#  520: 'Covid Analytics',
#  521: ' Pytorch',
#  522: ' MoCo',
#  523: ' AI',
#  524: ' segment',
#  525: ' Resnet50',
#  526: ' AI',
#  527: ' 3D',
#  528: ' Slicer',
#  529: ' MoCo',
#  530: ' SPYD',
#  531: ' SOMATOM Drive',
#  532: ' Discovery',
#  533: ' Optima',
#  534: ' SPYD',
#  535: ' pandas',
#  536: ' scikit',
#  537: ' learn',
#  538: ' AI',
#  539: ' segment',
#  540: ' MoCo',
#  541: 'FaceTime',
#  542: 'ImageJ',
#  543: ' ImageJ',
#  544: ' GraphPad Prism',
#  545: ' SRDFDS',
#  546: 'Matlab',
#  547: ' IDEFO',
#  548: ' Matlab',
#  549: 'SIUH',
#  550: ' Verizon',
#  551: 'Sunrise Clinical Manager',
#  552: 'SPSS',
#  553: ' SPSS PROCESS Macro',
#  554: 'FEDORA',
#  555: 'UroSoMe',
#  556: ' Survey Monkey',
#  557: 'Wolfram Mathematica',
#  558: ' MAT',
#  559: ' Matlab',
#  560: 'Google Scholar',
#  561: 'CASMIM',
#  562: ' CASMIM',
#  563: ' CASMIM',
#  564: ' CASMIM',
#  565: 'Datacolor',
#  566: 'WinMatch',
#  567: ' Sedfit',
#  568: ' Sedphat',
#  569: ' SEDNTERP',
#  570: ' Clampfit',
#  571: 'PERSAL',
#  572: ' PERSAL',
#  573: 'Medscape',
#  574: ' Google Scholar',
#  575: 'Google Scholar',
#  576: 'Xpert Xpress',
#  577: ' GeneXpert',
#  578: ' EP',
#  579: ' Excel',
#  580: ' ID NOW',
#  581: ' Xpert Xpress',
#  582: ' Cobas',
#  583: ' Cepheid',
#  584: ' Xpert Xpress',
#  585: ' Simplexa',
#  586: 'Python',
#  587: ' sklearn',
#  588: ' numpy',
#  589: ' pandas',
#  590: ' scipy',
#  591: ' COVID DATA SAVE LIVES',
#  592: 'SuPER',
#  593: ' SuPER',
#  594: ' SuPER',
#  595: ' SuPER',
#  596: ' SuPER',
#  597: ' SuPER',
#  598: ' SuPER',
#  599: ' Infernal',
#  600: ' BWA',
#  601: ' SuPER',
#  602: ' SuPER (Position Exploration with',
#  603: ' SuPER',
#  604: ' HISAT2',
#  605: ' SuPER',
#  606: ' SuPER',
#  607: ' Muscle',
#  608: ' FastTree',
#  609: ' SuPER',
#  610: ' SuPER (Subgenomic mRNA Position Exploration with RNA - sequencing)',
#  611: ' SuPER',
#  612: ' RDP4',
#  613: ' SuPER',
#  614: ' VARNA',
#  615: ' SuPER',
#  616: ' SuPER',
#  617: ' SuPER',
#  618: ' SuPER',
#  619: ' SuPER',
#  620: ' SuPER',
#  621: ' SuPER',
#  622: ' SuPER',
#  623: ' SuPER',
#  624: ' SuPER',
#  625: ' Muscle',
#  626: ' Mash',
#  627: ' RDP4',
#  628: ' SIMPLOT',
#  629: ' RDP4',
#  630: ' Infernal',
#  631: ' SuPER',
#  632: 'Explorys',
#  633: ' Explorys',
#  634: ' Explorys Explore Cohort Discovery',
#  635: ' Explorys',
#  636: ' Watson Health Explorys',
#  637: ' Explorys Cohort Discovery',
#  638: ' Explorys',
#  639: ' SNOMED',
#  640: ' CT',
#  641: ' Explorys',
#  642: ' SNOMED',
#  643: ' CT',
#  644: ' SNOMED',
#  645: ' CT',
#  646: ' Explorys',
#  647: 'ESE Finder',
#  648: ' ESR search',
#  649: ' EMBL',
#  650: ' RBPmap',
#  651: ' RBPmap',
#  652: ' ESEFinder',
#  653: 'KINETIC',
#  654: ' LIGAND',
#  655: ' Scatcbard',
#  656: ' LIGAND',
#  657: 'CodiEsp',
#  658: ' CodiEsp',
#  659: ' CodiEsp',
#  660: ' CLEF',
#  661: ' CodiEsp',
#  662: ' CLEF',
#  663: ' CodiEsp',
#  664: ' CodiEsp',
#  665: ' CodiEsp',
#  666: ' CodiEsp',
#  667: ' CodiEsp',
#  668: ' CodiEsp',
#  669: ' CodiEsp',
#  670: ' CLEF',
#  671: ' CLEF',
#  672: ' CommonCrawl',
#  673: 'FoldX',
#  674: ' ADAR',
#  675: ' R',
#  676: ' R',
#  677: ' pySam',
#  678: ' CirSeq',
#  679: ' R',
#  680: ' CirSeq',
#  681: ' CirSeq',
#  682: ' PyMol',
#  683: ' PyMol',
#  684: ' adar',
#  685: ' R',
#  686: ' ggseqlogo',
#  687: ' CirSeq',
#  688: ' CirSeq',
#  689: ' FitnessEstimator',
#  690: ' CirSeq',
#  691: ' CirSeq',
#  692: ' R',
#  693: ' AtoGorTtoC',
#  694: ' usingPySam',
#  695: ' py',
#  696: ' CirSeq',
#  697: ' CirSeq',
#  698: ' MultiMatch',
#  699: ' Genescript',
#  700: ' R',
#  701: ' MaximumLikelihoodEstimation _ Q20 _ Zach R',
#  702: ' MODELER',
#  703: ' FitnessEstimator',
#  704: ' CirSeq',
#  705: 'ImageJ',
#  706: ' StepOne',
#  707: ' ImageJ',
#  708: 'Primer Explorer',
#  709: ' MEGABLAST',
#  710: 'EULAR',
#  711: 'EFE Verifica',
#  712: ' PolitiFact',
#  713: ' PolitiFact',
#  714: ' LeadStories',
#  715: ' PolitiFact',
#  716: ' Snopes',
#  717: ' EFE Verifica',
#  718: ' PolitiFact',
#  719: ' PolitiFact',
#  720: ' PolitiFact',
#  721: ' Miniver',
#  722: ' JCDAtrasto',
#  723: ' PolitiFact',
#  724: ' PolitiFact - - Meter',
#  725: ' Politi',
#  726: ' Fact',
#  727: ' PolitiFact',
#  728: ' EuroMOMO',
#  729: ' Miniver',
#  730: ' PolitiFact',
#  731: ' Lead',
#  732: ' PolitiFact',
#  733: ' LeadStories',
#  734: 'mNGS',
#  735: 'MegAlign',
#  736: ' MegAlign',
#  737: ' Clustal W',
#  738: ' MegAlign',
#  739: ' BLAST',
#  740: 'Leica microsystems (LAS AF)',
#  741: ' Leica microsystems (LAS AF)',
#  742: ' NIH Image - J',
#  743: 'MACRO®',
#  744: ' Stata',
#  745: ' coArtHA',
#  746: ' MACRO®',
#  747: 'ROSETTA',
#  748: ' Enrich',
#  749: 'cuSPARSE',
#  750: ' NaSt3DGP',
#  751: ' ARPACK',
#  752: ' PETSc',
#  753: ' Eigen',
#  754: ' SPARSPAK',
#  755: ' cuSPARSE',
#  756: ' Free Software',
#  757: ' Gerris Flow Solver',
#  758: ' ENSE',
#  759: 'OPLS',
#  760: ' DA',
#  761: ' OPLS',
#  762: ' DA',
#  763: 'STATA',
#  764: 'DovePress',
#  765: ' Survey Monkey',
#  766: 'HISAT2',
#  767: ' GOATOOLS',
#  768: ' Trinity',
#  769: ' lme4',
#  770: ' SARTools',
#  771: ' Ensembl',
#  772: ' BUSCO',
#  773: ' FastQC',
#  774: ' DESeq2',
#  775: ' edgeR',
#  776: ' SARTools',
#  777: ' edgeR',
#  778: ' Ensembl',
#  779: ' RNAmmer',
#  780: ' RSEM',
#  781: ' Ensembl',
#  782: ' GOATOOLS',
#  783: ' FeatureCounts',
#  784: ' Trimmomatic',
#  785: ' DESeq2',
#  786: ' EdgeR',
#  787: ' GOATOOLS',
#  788: ' GOATOOLS',
#  789: ' SARTools',
#  790: ' blast',
#  791: ' Bowtie',
#  792: ' RSEM',
#  793: ' FeatureCounts',
#  794: 'Jpred4',
#  795: ' MEGA',
#  796: ' MEME',
#  797: ' Datamonkey',
#  798: ' Jpred4',
#  799: ' Sequencher',
#  800: 'Knowledge Education',
#  801: ' MED',
#  802: ' Stud',
#  803: ' LimeSurvey',
#  804: ' SPSS Statistics',
#  805: ' Webex Meeting',
#  806: 'SmartPLS3',
#  807: ' Smart PLS',
#  808: 'R',
#  809: ' R Foundation for Statistical Computing',
#  810: 'GraphPad',
#  811: ' Prism',
#  812: ' ImageJ',
#  813: 'Coot',
#  814: ' REFMAC',
#  815: ' GraphPad',
#  816: ' PHASER',
#  817: ' XDS',
#  818: ' SCALA',
#  819: ' CCP4 suite',
#  820: 'VSD',
#  821: 'SIMCA',
#  822: ' SPSS',
#  823: ' DA',
#  824: ' Olink',
#  825: 'Geneious Prime',
#  826: ' Geneious Prime',
#  827: 'JITAIs',
#  828: ' Scopus',
#  829: 'PortaCount',
#  830: ' PortaCount',
#  831: ' Bitrex',
#  832: 'ClinGen',
#  833: ' ACMG',
#  834: ' AMP',
#  835: ' LMNA',
#  836: 'SiteEngine',
#  837: ' SiteEngine',
#  838: ' MultiProt',
#  839: ' SiteEngine',
#  840: ' SiteEngine',
#  841: ' SiteEngine',
#  842: ' SiteEngine',
#  843: ' SiteEngine',
#  844: ' SiteEngine',
#  845: ' SiteEngine',
#  846: ' SiteEngine',
#  847: ' SiteEngine',
#  848: ' SiteEngine',
#  849: ' SiteEngine',
#  850: ' SiteEngine',
#  851: ' SiteEngine',
#  852: ' SiteEngine',
#  853: ' SiteEngine',
#  854: ' SiteEngine',
#  855: ' SiteEngine',
#  856: ' SiteEngine',
#  857: ' SiteEngine',
#  858: ' SiteEngine',
#  859: ' SiteEngine',
#  860: ' SiteEngine',
#  861: ' SiteEngine',
#  862: ' SiteEngine',
#  863: ' SiteEngine',
#  864: ' Relibase',
#  865: ' SiteEngine',
#  866: ' MultiProt',
#  867: ' SiteEngine',
#  868: ' SiteEngine',
#  869: ' SiteEngine',
#  870: ' SiteEngine',
#  871: ' SiteEngine',
#  872: ' SiteEngine',
#  873: ' SiteEngine',
#  874: ' JESS',
#  875: ' CASTp',
#  876: ' SiteEngine',
#  877: ' SiteEngine',
#  878: ' SiteEngine',
#  879: ' SiteEngine',
#  880: ' SiteEngine',
#  881: 'JMP',
#  882: ' SAS',
#  883: 'SAMtools',
#  884: ' Bowtie',
#  885: ' GraphPad Prism',
#  886: ' FlowJo',
#  887: ' GraphPad Prism',
#  888: 'MeshFix',
#  889: 'SAS',
#  890: ' mirPath',
#  891: ' DIANA',
#  892: ' Cluster',
#  893: ' Java TreeView',
#  894: ' miRecords',
#  895: ' miRanda',
#  896: ' miR2Disease',
#  897: ' PhenomiR',
#  898: ' SM2miR',
#  899: ' PharmacomiREpimiR',
#  900: ' SDS',
#  901: 'Stata',
#  902: 'SPSS',
#  903: 'ZetaGene',
#  904: 'factoextra R',
#  905: 'GraphPad Prism',
#  906: ' PolyPhen',
#  907: ' CDNN',
#  908: 'SOAP',
#  909: ' ANTIGEN',
#  910: ' PSIGNAL',
#  911: ' PCGene package',
#  912: ' PSEARCH',
#  913: ' COIL',
#  914: ' CLUSTAL',
#  915: ' Intelligenetics',
#  916: ' COIL',
#  917: ' SOAP',
#  918: ' PCGene',
#  919: ' COIL',
#  920: 'Stata',
#  921: ' Cochrane Risk of Bias Tool',
#  922: ' Ovid MEDLINE',
#  923: ' EndNote X9',
#  924: 'AutoMotifServer',
#  925: ' GPS',
#  926: ' KinasePhos',
#  927: ' NetPhosK',
#  928: ' PPSP',
#  929: ' PredPhosphoScansite',
#  930: ' Meta Predictor',
#  931: ' Sulfinator',
#  932: ' PPSP',
#  933: ' NetPhosK',
#  934: ' PredPhospho',
#  935: ' NetPhosK',
#  936: ' AMS3',
#  937: ' PTM',
#  938: ' Archive',
#  939: ' KinasePhos',
#  940: ' Sequence Generator',
#  941: ' Predictor',
#  942: ' Predictor',
#  943: ' AutoMotifServer (AMS)',
#  944: ' AMS',
#  945: ' MS',
#  946: ' Excel',
#  947: ' LOOCV',
#  948: ' NetPhos',
#  949: ' NetPhosK',
#  950: ' Phospho',
#  951: ' ELM',
#  952: ' NetPhosK',
#  953: ' NetPhosK',
#  954: ' NetPhosK',
#  955: ' Scansite',
#  956: ' NetPhos',
#  957: ' Net',
#  958: ' PhosK',
#  959: ' NetOGlyc',
#  960: ' NetNGlyc',
#  961: ' DictyOGlyc',
#  962: ' YinOYang',
#  963: ' AMS',
#  964: ' AMS',
#  965: ' Predictor',
#  966: ' NetPhosK',
#  967: ' AMS',
#  968: ' Meta Predictor',
#  969: ' AMS3',
#  970: ' AMS',
#  971: ' AMS',
#  972: ' AMS3',
#  973: ' PROSITE',
#  974: ' NetPhosK',
#  975: ' AMS',
#  976: ' AutoMotif Server',
#  977: ' AMS',
#  978: ' ELM',
#  979: ' NetPhosK',
#  980: ' Linux',
#  981: ' LOOCV',
#  982: ' PHOSITE',
#  983: ' KinasePhos',
#  984: ' NetPhosK',
#  985: ' PredPhospho',
#  986: ' Scansite',
#  987: ' Apache',
#  988: ' AMS',
#  989: 'POP',
#  990: ' PopGen',
#  991: ' GenAlEx',
#  992: 'COMPERA',
#  993: 'R',
#  994: 'PCA',
#  995: ' GA',
#  996: ' CA',
#  997: ' PCA',
#  998: ' GA',
#  999: ' PCA',
#  ...}

# %% [markdown]
# In this case, there are empty cases which make the function value_counts sum up software mentons with an additional empty space prior the string as distinct. Therefore, the function remove_empty_spaces(d) takes a dictionary and removes an empty space at the first position of a string.

# %%
def remove_empty_spaces(dic):
    """ Function removing an empty space at the first position of a string. 
    """
    for i in dic:
        if dic[i][:1] == " ":
            dic[i] = dic[i][1:] #.strip() -> Improvement
    return dic

# %%
software_dict = remove_empty_spaces(software_dict)
software_dict
# Out:
# {0: 'Google Street View',
#  1: 'SEGG',
#  2: 'STATA',
#  3: 'IAMCEST',
#  4: 'SPSS',
#  5: 'R',
#  6: 'MassARRAY Typer Analyzer',
#  7: 'Wechat',
#  8: 'SPSS Statistics',
#  9: 'Statistical Package for Social Sciences (SPSS)',
#  10: 'BD CBA',
#  11: 'STATA',
#  12: 'STATA',
#  13: 'Statacorp',
#  14: 'SPSS',
#  15: 'SPSS',
#  16: 'geNorm',
#  17: 'GraphPad Prism',
#  18: 'GraphPad',
#  19: 'Cellranger',
#  20: 'R',
#  21: 'Seurat',
#  22: 'ggplot2',
#  23: 'LinRegPCR',
#  24: 'GramA',
#  25: 'R package edgeR',
#  26: 'R package edgeR',
#  27: 'R package edgeR',
#  28: 'STAR',
#  29: 'FastQC',
#  30: 'R package ALDEx2',
#  31: 'ImageJ',
#  32: 'PfAlbas',
#  33: 'SAM',
#  34: 'MORO Praxis',
#  35: 'MORO',
#  36: 'R2HC',
#  37: 'Singapour',
#  38: 'PRESET',
#  39: 'Google Trends (GT',
#  40: 'GT',
#  41: 'SINUS',
#  42: 'VICTIMES',
#  43: 'Spirocall',
#  44: 'LIBSVM',
#  45: 'MATLAB voicebox',
#  46: 'openS',
#  47: 'MILE',
#  48: 'DP',
#  49: 'DP',
#  50: 'DSGVO',
#  51: 'iOS',
#  52: 'DSGVO',
#  53: 'PEPP',
#  54: 'PT',
#  55: 'DP',
#  56: '3T',
#  57: 'REDCapbased',
#  58: 'REDCap',
#  59: 'Research Electronic Data Capture',
#  60: 'R',
#  61: 'DDCNN',
#  62: 'AR',
#  63: 'INCART',
#  64: 'CLSM',
#  65: 'MIT',
#  66: 'BIH',
#  67: 'SUP',
#  68: 'INCART',
#  69: 'CLSM',
#  70: 'CLSM',
#  71: 'INCART',
#  72: 'Adam',
#  73: 'SOMTE',
#  74: 'SMOTE',
#  75: 'SMOTE',
#  76: 'CLSM',
#  77: 'INCART',
#  78: 'CLSM',
#  79: 'CLSM',
#  80: 'INCART',
#  81: 'CLSM',
#  82: 'CLSM',
#  83: 'SPSS',
#  84: 'SPSS',
#  85: 'CT Scan',
#  86: 'NCCS',
#  87: 'GraphPad Prism',
#  88: 'GraphPad',
#  89: 'Zen Zeiss',
#  90: 'FlowJo',
#  91: 'Zen Zeiss',
#  92: 'MCT',
#  93: 'Ribo',
#  94: 'Ribo',
#  95: 'Ribo',
#  96: 'Seq',
#  97: 'Random Forest',
#  98: 'LOOCV',
#  99: 'branch',
#  100: 'HDP',
#  101: 'Mbranch',
#  102: 'LAMP',
#  103: 'NEAR',
#  104: 'LAMP',
#  105: 'NEAR',
#  106: 'GISAID',
#  107: 'MAFFT',
#  108: 'Bioedit',
#  109: 'SwissModel',
#  110: 'HHpred',
#  111: 'MEME',
#  112: 'Mutant2',
#  113: 'TMHMM',
#  114: 'Protter',
#  115: 'SwissModel',
#  116: 'HHPred',
#  117: 'Jpred',
#  118: 'IQ',
#  119: 'TREE',
#  120: 'IQ',
#  121: 'TREE',
#  122: 'ACS',
#  123: 'GISAID',
#  124: 'Py',
#  125: 'MOL',
#  126: 'Jpred',
#  127: 'TMHMM',
#  128: 'Protter',
#  129: 'Tasser',
#  130: 'Tasser',
#  131: 'Adaptive Evolution Server',
#  132: 'DECNEO',
#  133: 'DECNEO',
#  134: 'numpy',
#  135: 'scipy',
#  136: 'pandas',
#  137: 'scikit',
#  138: 'learn',
#  139: 'matplotlib',
#  140: 'PyIOmica',
#  141: 'Metascape',
#  142: 'PyPI',
#  143: 'DECNEO',
#  144: 'DECNEO',
#  145: 'CellRanger',
#  146: 'Metascape',
#  147: 'PanglaoDB',
#  148: 'R',
#  149: 'gravity',
#  150: 'Metascape',
#  151: 'DECNEO',
#  152: 'Alona',
#  153: 'DECNEO',
#  154: 'CellRanger',
#  155: 'DECNEO',
#  156: 'DECNEO',
#  157: 'DECNEO',
#  158: 'Metascape',
#  159: 'DECNEO (DEndrogram of Co - expression with Evolutionary Conservation and Network Enrichment Ordering)',
#  160: 'DECNEO',
#  161: 'Snowmass',
#  162: 'Metascape',
#  163: 'SPSS',
#  164: 'Ensembl',
#  165: 'BioMart',
#  166: 'REVIGO',
#  167: 'Cytoscape',
#  168: 'Cytoscape',
#  169: 'ClueGO',
#  170: 'ReviGO',
#  171: 'VetScan',
#  172: 'ReviGO',
#  173: 'Cytoscape',
#  174: 'REVIGO',
#  175: 'SimRel',
#  176: 'Cytoscape',
#  177: 'ClueGO',
#  178: 'GraphPad prism',
#  179: 'GraphPad prism',
#  180: 'QSR NVivo',
#  181: 'Engage',
#  182: 'SPSS',
#  183: 'R',
#  184: 'R Foundation for Statistical',
#  185: 'SAS',
#  186: 'STATA',
#  187: 'CONEVAL',
#  188: 'Curevac',
#  189: 'Stata MP15',
#  190: 'PROLISA',
#  191: 'Blood Sugar Lounge',
#  192: 'COVIDX',
#  193: 'Net',
#  194: 'Inception',
#  195: 'InceptionV3',
#  196: 'Xception',
#  197: 'MobileNetV2',
#  198: 'XceptionNet',
#  199: 'GitHub',
#  200: 'Google Scholar',
#  201: 'PAR',
#  202: 'PAR',
#  203: 'ENT',
#  204: 'QoL',
#  205: 'PAR',
#  206: 'QoL',
#  207: 'PAR',
#  208: 'ENT',
#  209: 'QoL',
#  210: 'AUDiaL',
#  211: 'Semantic Annotator for Inkscape (SAI)',
#  212: 'AUDiaL',
#  213: 'AUDiaL',
#  214: 'AUDiaL',
#  215: 'AUDiaL',
#  216: 'AUDiaL',
#  217: 'AUDiaL',
#  218: 'AUDiaL',
#  219: 'AUDiaL',
#  220: 'AUDiaL',
#  221: 'AUDiaL',
#  222: 'AUDiaL',
#  223: 'AUDiaL',
#  224: 'AUDiaL',
#  225: 'AUDiaL',
#  226: 'AUDiaL',
#  227: 'AUDiaL (Accessible Universal Diagrams through Language)',
#  228: 'AUDiaL',
#  229: 'AUDiaL',
#  230: 'AUDiaL',
#  231: 'AUDiaL',
#  232: 'AUDiaL',
#  233: 'AUDiaL',
#  234: 'AUDiaL (Accessible Universal Diagrams through Language)',
#  235: 'AUDiaL',
#  236: 'AUDiaL',
#  237: 'AUDiaL',
#  238: 'AUDiaL',
#  239: 'TCGA2STAT',
#  240: 'SSL',
#  241: 'netDx',
#  242: 'iDRW',
#  243: 'iDRW',
#  244: 'netDx',
#  245: 'iDRW',
#  246: 'netDx',
#  247: 'iDRW',
#  248: 'OMICSBind',
#  249: 'netDx',
#  250: 'iDRW',
#  251: 'iDRW',
#  252: 'netDx',
#  253: 'iDRW',
#  254: 'netDx',
#  255: 'iDRW',
#  256: 'iDRW',
#  257: 'ToppGenet',
#  258: 'OMICSBind',
#  259: 'TCGA2STAT',
#  260: 'iDRW',
#  261: 'netDx',
#  262: 'SSL Omics',
#  263: 'SSL Omics',
#  264: 'iDRW',
#  265: 'netDx',
#  266: 'SSL',
#  267: 'Graph',
#  268: '- Pad Prizm',
#  269: 'Graph',
#  270: '- Pad',
#  271: 'GenScript',
#  272: 'SPSS Statistics',
#  273: 'NEWS',
#  274: 'Original',
#  275: 'XPRIZE',
#  276: 'XPRIZE',
#  277: 'CODATA',
#  278: 'XPRIZE',
#  279: 'XPRIZE Pandemic',
#  280: 'XPRIZE',
#  281: 'Idea Builder',
#  282: 'Open COVID Pledge',
#  283: 'CODATA',
#  284: 'OSMS',
#  285: 'XPRIZE',
#  286: 'CODATA',
#  287: 'ACCORD',
#  288: 'INGSA',
#  289: 'XPRIZE',
#  290: 'Uber',
#  291: 'CODATA',
#  292: 'COVID Commons',
#  293: 'RESOLVE',
#  294: 'OSMS',
#  295: 'XPRIZE',
#  296: 'XPRIZE',
#  297: 'GraphPad Prism',
#  298: 'GraphPad',
#  299: 'LNRE',
#  300: 'LNRE',
#  301: 'LNRE',
#  302: 'TE',
#  303: 'Realpolitik',
#  304: 'Google Scholar',
#  305: 'SPSS Statistics',
#  306: 'Prism',
#  307: 'GraphPad',
#  308: 'RECOVERY',
#  309: 'Dantec',
#  310: 'Dynam',
#  311: 'icStudio',
#  312: 'QuantaSoft',
#  313: 'SPAR',
#  314: 'SPAR',
#  315: 'JEE',
#  316: 'JEE',
#  317: 'Cochrane',
#  318: 'Review Manager',
#  319: 'Cochrane',
#  320: 'Review Manager',
#  321: 'PRISMA',
#  322: 'Vital',
#  323: 'Vital',
#  324: 'MODBUS',
#  325: 'XAI',
#  326: 'Vital',
#  327: 'Vital',
#  328: 'Vital',
#  329: 'SWAMP',
#  330: 'Vital',
#  331: 'Cenote',
#  332: 'SPSS',
#  333: 'SPSS',
#  334: 'SPSS Statistics',
#  335: 'Oracle',
#  336: 'SPSS Statistics',
#  337: 'ANOSIM',
#  338: 'OptiClust',
#  339: 'CANOCO',
#  340: 'Analysis of Similarity (ANOSIM)',
#  341: 'Gen',
#  342: 'AlEx',
#  343: 'anosim',
#  344: 'mothur',
#  345: 'mothur',
#  346: 'unifrac',
#  347: 'mothur',
#  348: 'LEfSe',
#  349: 'PSORT',
#  350: 'PSORT',
#  351: 'SPSS',
#  352: 'ETAT',
#  353: 'ETAT',
#  354: 'PRISM',
#  355: 'FV',
#  356: 'Forrest',
#  357: 'Stata',
#  358: 'Mendeley Desktop',
#  359: 'STATA',
#  360: 'excel',
#  361: 'endnote',
#  362: 'Scopus',
#  363: 'ScPL',
#  364: 'DGGRL',
#  365: 'ANOSIM',
#  366: 'R',
#  367: 'Excel',
#  368: 'SPSS',
#  369: 'ECVIM',
#  370: 'Genome Analysis ToolKit',
#  371: 'SUPERSAT',
#  372: 'ACVIM',
#  373: 'Xstrain',
#  374: 'Burdick Holter Analysis',
#  375: 'Prism7',
#  376: 'ImmTT4',
#  377: 'CataT4',
#  378: 'GraphPad Prism',
#  379: 'SigmaPlot',
#  380: 'Systat',
#  381: 'NSIP',
#  382: 'ProMED',
#  383: 'mail',
#  384: 'FluNet',
#  385: 'FluID',
#  386: 'DOCS',
#  387: 'GPHIN',
#  388: 'GOARN',
#  389: 'GOARN',
#  390: 'GOARN',
#  391: 'ProMED',
#  392: 'mail',
#  393: 'GraphPad Prism',
#  394: 'GraphPad Prism',
#  395: 'GRECCAR2',
#  396: 'STENT',
#  397: 'IDEAL',
#  398: 'GRECCAR',
#  399: 'GRECCAR2',
#  400: 'GRECCAR',
#  401: 'SmartPLS',
#  402: 'KakaoTalk',
#  403: 'SPSS Statistics',
#  404: 'Smart PLS',
#  405: 'Google Drive',
#  406: 'KakaoTalk',
#  407: 'ImageJ',
#  408: 'SPSS',
#  409: 'qBase',
#  410: 'Image J',
#  411: 'geNorm',
#  412: 'UFibro',
#  413: 'ImageJ',
#  414: 'REDCap',
#  415: 'Research Electronic Data Capture (REDCap)',
#  416: 'REDCap',
#  417: 'Navigator Network NET',
#  418: 'NTS',
#  419: 'NET',
#  420: 'Tensorflow',
#  421: 'DeepLift',
#  422: 'DeepLift',
#  423: 'DANN',
#  424: 'SANN',
#  425: 'R',
#  426: 'RStudio',
#  427: 'R',
#  428: 'R',
#  429: 'WhatsApp TM',
#  430: 'REDCap',
#  431: 'mfold',
#  432: 'mfold',
#  433: 'mfold',
#  434: 'mfold',
#  435: 'mfold',
#  436: 'Open',
#  437: 'Open Science',
#  438: 'Open',
#  439: 'CO',
#  440: 'CIN',
#  441: 'CORD',
#  442: 'gensim',
#  443: 'VOSviewer',
#  444: 'VOSviewer',
#  445: 'ScispaCy',
#  446: 'VOSviewer',
#  447: 'Altmetric',
#  448: 'Dimensions',
#  449: 'WoS',
#  450: 'strict',
#  451: 'Altmetric',
#  452: 'Dimensions',
#  453: 'Altmetric',
#  454: 'Altmetric',
#  455: 'Altmetric',
#  456: 'PMC',
#  457: 'VOSviewer',
#  458: 'Altmetric',
#  459: 'Excel',
#  460: 'EPI',
#  461: 'INFO',
#  462: 'SAS',
#  463: 'SAS',
#  464: 'SPSS',
#  465: 'SPSS',
#  466: 'Flow',
#  467: 'Stata',
#  468: 'GraphPad Prism',
#  469: 'Review Manager',
#  470: 'Adam',
#  471: 'fastText',
#  472: 'ELMO',
#  473: 'Skype',
#  474: 'Facetime',
#  475: 'MESH',
#  476: 'MEDLINE',
#  477: 'KAON',
#  478: 'KAON',
#  479: 'Headache',
#  480: 'KAON',
#  481: 'KAON',
#  482: 'KAON',
#  483: 'KAON',
#  484: 'MEDLINE',
#  485: 'MEDLINE',
#  486: 'KAON',
#  487: 'GPC',
#  488: 'GPC',
#  489: 'Matlab',
#  490: 'Matlab',
#  491: 'NL Actief',
#  492: 'Excel',
#  493: 'Excel',
#  494: 'Optimas',
#  495: 'Optimast',
#  496: 'SPSS',
#  497: 'SPSS',
#  498: 'Excel',
#  499: 'VMD',
#  500: 'GNUPLOT',
#  501: 'ProDy',
#  502: 'SPSS',
#  503: 'CONSORT',
#  504: 'FILEMAKER PRO',
#  505: 'ANALYSIS',
#  506: 'Stata',
#  507: 'Biacore',
#  508: 'MEGA',
#  509: 'eRisk',
#  510: 'Reddit',
#  511: 'eRisk',
#  512: 'Linguistic Inquiry and Word Count LIWC',
#  513: 'LIWC',
#  514: 'Reddit',
#  515: 'LIWC',
#  516: 'Early Risk Prediction on Internet (eRisk) Linguistics and Clinical Psychology (CLPsych)',
#  517: 'eRisk',
#  518: 'Worldometers',
#  519: 'SmartPLS',
#  520: 'Covid Analytics',
#  521: 'Pytorch',
#  522: 'MoCo',
#  523: 'AI',
#  524: 'segment',
#  525: 'Resnet50',
#  526: 'AI',
#  527: '3D',
#  528: 'Slicer',
#  529: 'MoCo',
#  530: 'SPYD',
#  531: 'SOMATOM Drive',
#  532: 'Discovery',
#  533: 'Optima',
#  534: 'SPYD',
#  535: 'pandas',
#  536: 'scikit',
#  537: 'learn',
#  538: 'AI',
#  539: 'segment',
#  540: 'MoCo',
#  541: 'FaceTime',
#  542: 'ImageJ',
#  543: 'ImageJ',
#  544: 'GraphPad Prism',
#  545: 'SRDFDS',
#  546: 'Matlab',
#  547: 'IDEFO',
#  548: 'Matlab',
#  549: 'SIUH',
#  550: 'Verizon',
#  551: 'Sunrise Clinical Manager',
#  552: 'SPSS',
#  553: 'SPSS PROCESS Macro',
#  554: 'FEDORA',
#  555: 'UroSoMe',
#  556: 'Survey Monkey',
#  557: 'Wolfram Mathematica',
#  558: 'MAT',
#  559: 'Matlab',
#  560: 'Google Scholar',
#  561: 'CASMIM',
#  562: 'CASMIM',
#  563: 'CASMIM',
#  564: 'CASMIM',
#  565: 'Datacolor',
#  566: 'WinMatch',
#  567: 'Sedfit',
#  568: 'Sedphat',
#  569: 'SEDNTERP',
#  570: 'Clampfit',
#  571: 'PERSAL',
#  572: 'PERSAL',
#  573: 'Medscape',
#  574: 'Google Scholar',
#  575: 'Google Scholar',
#  576: 'Xpert Xpress',
#  577: 'GeneXpert',
#  578: 'EP',
#  579: 'Excel',
#  580: 'ID NOW',
#  581: 'Xpert Xpress',
#  582: 'Cobas',
#  583: 'Cepheid',
#  584: 'Xpert Xpress',
#  585: 'Simplexa',
#  586: 'Python',
#  587: 'sklearn',
#  588: 'numpy',
#  589: 'pandas',
#  590: 'scipy',
#  591: 'COVID DATA SAVE LIVES',
#  592: 'SuPER',
#  593: 'SuPER',
#  594: 'SuPER',
#  595: 'SuPER',
#  596: 'SuPER',
#  597: 'SuPER',
#  598: 'SuPER',
#  599: 'Infernal',
#  600: 'BWA',
#  601: 'SuPER',
#  602: 'SuPER (Position Exploration with',
#  603: 'SuPER',
#  604: 'HISAT2',
#  605: 'SuPER',
#  606: 'SuPER',
#  607: 'Muscle',
#  608: 'FastTree',
#  609: 'SuPER',
#  610: 'SuPER (Subgenomic mRNA Position Exploration with RNA - sequencing)',
#  611: 'SuPER',
#  612: 'RDP4',
#  613: 'SuPER',
#  614: 'VARNA',
#  615: 'SuPER',
#  616: 'SuPER',
#  617: 'SuPER',
#  618: 'SuPER',
#  619: 'SuPER',
#  620: 'SuPER',
#  621: 'SuPER',
#  622: 'SuPER',
#  623: 'SuPER',
#  624: 'SuPER',
#  625: 'Muscle',
#  626: 'Mash',
#  627: 'RDP4',
#  628: 'SIMPLOT',
#  629: 'RDP4',
#  630: 'Infernal',
#  631: 'SuPER',
#  632: 'Explorys',
#  633: 'Explorys',
#  634: 'Explorys Explore Cohort Discovery',
#  635: 'Explorys',
#  636: 'Watson Health Explorys',
#  637: 'Explorys Cohort Discovery',
#  638: 'Explorys',
#  639: 'SNOMED',
#  640: 'CT',
#  641: 'Explorys',
#  642: 'SNOMED',
#  643: 'CT',
#  644: 'SNOMED',
#  645: 'CT',
#  646: 'Explorys',
#  647: 'ESE Finder',
#  648: 'ESR search',
#  649: 'EMBL',
#  650: 'RBPmap',
#  651: 'RBPmap',
#  652: 'ESEFinder',
#  653: 'KINETIC',
#  654: 'LIGAND',
#  655: 'Scatcbard',
#  656: 'LIGAND',
#  657: 'CodiEsp',
#  658: 'CodiEsp',
#  659: 'CodiEsp',
#  660: 'CLEF',
#  661: 'CodiEsp',
#  662: 'CLEF',
#  663: 'CodiEsp',
#  664: 'CodiEsp',
#  665: 'CodiEsp',
#  666: 'CodiEsp',
#  667: 'CodiEsp',
#  668: 'CodiEsp',
#  669: 'CodiEsp',
#  670: 'CLEF',
#  671: 'CLEF',
#  672: 'CommonCrawl',
#  673: 'FoldX',
#  674: 'ADAR',
#  675: 'R',
#  676: 'R',
#  677: 'pySam',
#  678: 'CirSeq',
#  679: 'R',
#  680: 'CirSeq',
#  681: 'CirSeq',
#  682: 'PyMol',
#  683: 'PyMol',
#  684: 'adar',
#  685: 'R',
#  686: 'ggseqlogo',
#  687: 'CirSeq',
#  688: 'CirSeq',
#  689: 'FitnessEstimator',
#  690: 'CirSeq',
#  691: 'CirSeq',
#  692: 'R',
#  693: 'AtoGorTtoC',
#  694: 'usingPySam',
#  695: 'py',
#  696: 'CirSeq',
#  697: 'CirSeq',
#  698: 'MultiMatch',
#  699: 'Genescript',
#  700: 'R',
#  701: 'MaximumLikelihoodEstimation _ Q20 _ Zach R',
#  702: 'MODELER',
#  703: 'FitnessEstimator',
#  704: 'CirSeq',
#  705: 'ImageJ',
#  706: 'StepOne',
#  707: 'ImageJ',
#  708: 'Primer Explorer',
#  709: 'MEGABLAST',
#  710: 'EULAR',
#  711: 'EFE Verifica',
#  712: 'PolitiFact',
#  713: 'PolitiFact',
#  714: 'LeadStories',
#  715: 'PolitiFact',
#  716: 'Snopes',
#  717: 'EFE Verifica',
#  718: 'PolitiFact',
#  719: 'PolitiFact',
#  720: 'PolitiFact',
#  721: 'Miniver',
#  722: 'JCDAtrasto',
#  723: 'PolitiFact',
#  724: 'PolitiFact - - Meter',
#  725: 'Politi',
#  726: 'Fact',
#  727: 'PolitiFact',
#  728: 'EuroMOMO',
#  729: 'Miniver',
#  730: 'PolitiFact',
#  731: 'Lead',
#  732: 'PolitiFact',
#  733: 'LeadStories',
#  734: 'mNGS',
#  735: 'MegAlign',
#  736: 'MegAlign',
#  737: 'Clustal W',
#  738: 'MegAlign',
#  739: 'BLAST',
#  740: 'Leica microsystems (LAS AF)',
#  741: 'Leica microsystems (LAS AF)',
#  742: 'NIH Image - J',
#  743: 'MACRO®',
#  744: 'Stata',
#  745: 'coArtHA',
#  746: 'MACRO®',
#  747: 'ROSETTA',
#  748: 'Enrich',
#  749: 'cuSPARSE',
#  750: 'NaSt3DGP',
#  751: 'ARPACK',
#  752: 'PETSc',
#  753: 'Eigen',
#  754: 'SPARSPAK',
#  755: 'cuSPARSE',
#  756: 'Free Software',
#  757: 'Gerris Flow Solver',
#  758: 'ENSE',
#  759: 'OPLS',
#  760: 'DA',
#  761: 'OPLS',
#  762: 'DA',
#  763: 'STATA',
#  764: 'DovePress',
#  765: 'Survey Monkey',
#  766: 'HISAT2',
#  767: 'GOATOOLS',
#  768: 'Trinity',
#  769: 'lme4',
#  770: 'SARTools',
#  771: 'Ensembl',
#  772: 'BUSCO',
#  773: 'FastQC',
#  774: 'DESeq2',
#  775: 'edgeR',
#  776: 'SARTools',
#  777: 'edgeR',
#  778: 'Ensembl',
#  779: 'RNAmmer',
#  780: 'RSEM',
#  781: 'Ensembl',
#  782: 'GOATOOLS',
#  783: 'FeatureCounts',
#  784: 'Trimmomatic',
#  785: 'DESeq2',
#  786: 'EdgeR',
#  787: 'GOATOOLS',
#  788: 'GOATOOLS',
#  789: 'SARTools',
#  790: 'blast',
#  791: 'Bowtie',
#  792: 'RSEM',
#  793: 'FeatureCounts',
#  794: 'Jpred4',
#  795: 'MEGA',
#  796: 'MEME',
#  797: 'Datamonkey',
#  798: 'Jpred4',
#  799: 'Sequencher',
#  800: 'Knowledge Education',
#  801: 'MED',
#  802: 'Stud',
#  803: 'LimeSurvey',
#  804: 'SPSS Statistics',
#  805: 'Webex Meeting',
#  806: 'SmartPLS3',
#  807: 'Smart PLS',
#  808: 'R',
#  809: 'R Foundation for Statistical Computing',
#  810: 'GraphPad',
#  811: 'Prism',
#  812: 'ImageJ',
#  813: 'Coot',
#  814: 'REFMAC',
#  815: 'GraphPad',
#  816: 'PHASER',
#  817: 'XDS',
#  818: 'SCALA',
#  819: 'CCP4 suite',
#  820: 'VSD',
#  821: 'SIMCA',
#  822: 'SPSS',
#  823: 'DA',
#  824: 'Olink',
#  825: 'Geneious Prime',
#  826: 'Geneious Prime',
#  827: 'JITAIs',
#  828: 'Scopus',
#  829: 'PortaCount',
#  830: 'PortaCount',
#  831: 'Bitrex',
#  832: 'ClinGen',
#  833: 'ACMG',
#  834: 'AMP',
#  835: 'LMNA',
#  836: 'SiteEngine',
#  837: 'SiteEngine',
#  838: 'MultiProt',
#  839: 'SiteEngine',
#  840: 'SiteEngine',
#  841: 'SiteEngine',
#  842: 'SiteEngine',
#  843: 'SiteEngine',
#  844: 'SiteEngine',
#  845: 'SiteEngine',
#  846: 'SiteEngine',
#  847: 'SiteEngine',
#  848: 'SiteEngine',
#  849: 'SiteEngine',
#  850: 'SiteEngine',
#  851: 'SiteEngine',
#  852: 'SiteEngine',
#  853: 'SiteEngine',
#  854: 'SiteEngine',
#  855: 'SiteEngine',
#  856: 'SiteEngine',
#  857: 'SiteEngine',
#  858: 'SiteEngine',
#  859: 'SiteEngine',
#  860: 'SiteEngine',
#  861: 'SiteEngine',
#  862: 'SiteEngine',
#  863: 'SiteEngine',
#  864: 'Relibase',
#  865: 'SiteEngine',
#  866: 'MultiProt',
#  867: 'SiteEngine',
#  868: 'SiteEngine',
#  869: 'SiteEngine',
#  870: 'SiteEngine',
#  871: 'SiteEngine',
#  872: 'SiteEngine',
#  873: 'SiteEngine',
#  874: 'JESS',
#  875: 'CASTp',
#  876: 'SiteEngine',
#  877: 'SiteEngine',
#  878: 'SiteEngine',
#  879: 'SiteEngine',
#  880: 'SiteEngine',
#  881: 'JMP',
#  882: 'SAS',
#  883: 'SAMtools',
#  884: 'Bowtie',
#  885: 'GraphPad Prism',
#  886: 'FlowJo',
#  887: 'GraphPad Prism',
#  888: 'MeshFix',
#  889: 'SAS',
#  890: 'mirPath',
#  891: 'DIANA',
#  892: 'Cluster',
#  893: 'Java TreeView',
#  894: 'miRecords',
#  895: 'miRanda',
#  896: 'miR2Disease',
#  897: 'PhenomiR',
#  898: 'SM2miR',
#  899: 'PharmacomiREpimiR',
#  900: 'SDS',
#  901: 'Stata',
#  902: 'SPSS',
#  903: 'ZetaGene',
#  904: 'factoextra R',
#  905: 'GraphPad Prism',
#  906: 'PolyPhen',
#  907: 'CDNN',
#  908: 'SOAP',
#  909: 'ANTIGEN',
#  910: 'PSIGNAL',
#  911: 'PCGene package',
#  912: 'PSEARCH',
#  913: 'COIL',
#  914: 'CLUSTAL',
#  915: 'Intelligenetics',
#  916: 'COIL',
#  917: 'SOAP',
#  918: 'PCGene',
#  919: 'COIL',
#  920: 'Stata',
#  921: 'Cochrane Risk of Bias Tool',
#  922: 'Ovid MEDLINE',
#  923: 'EndNote X9',
#  924: 'AutoMotifServer',
#  925: 'GPS',
#  926: 'KinasePhos',
#  927: 'NetPhosK',
#  928: 'PPSP',
#  929: 'PredPhosphoScansite',
#  930: 'Meta Predictor',
#  931: 'Sulfinator',
#  932: 'PPSP',
#  933: 'NetPhosK',
#  934: 'PredPhospho',
#  935: 'NetPhosK',
#  936: 'AMS3',
#  937: 'PTM',
#  938: 'Archive',
#  939: 'KinasePhos',
#  940: 'Sequence Generator',
#  941: 'Predictor',
#  942: 'Predictor',
#  943: 'AutoMotifServer (AMS)',
#  944: 'AMS',
#  945: 'MS',
#  946: 'Excel',
#  947: 'LOOCV',
#  948: 'NetPhos',
#  949: 'NetPhosK',
#  950: 'Phospho',
#  951: 'ELM',
#  952: 'NetPhosK',
#  953: 'NetPhosK',
#  954: 'NetPhosK',
#  955: 'Scansite',
#  956: 'NetPhos',
#  957: 'Net',
#  958: 'PhosK',
#  959: 'NetOGlyc',
#  960: 'NetNGlyc',
#  961: 'DictyOGlyc',
#  962: 'YinOYang',
#  963: 'AMS',
#  964: 'AMS',
#  965: 'Predictor',
#  966: 'NetPhosK',
#  967: 'AMS',
#  968: 'Meta Predictor',
#  969: 'AMS3',
#  970: 'AMS',
#  971: 'AMS',
#  972: 'AMS3',
#  973: 'PROSITE',
#  974: 'NetPhosK',
#  975: 'AMS',
#  976: 'AutoMotif Server',
#  977: 'AMS',
#  978: 'ELM',
#  979: 'NetPhosK',
#  980: 'Linux',
#  981: 'LOOCV',
#  982: 'PHOSITE',
#  983: 'KinasePhos',
#  984: 'NetPhosK',
#  985: 'PredPhospho',
#  986: 'Scansite',
#  987: 'Apache',
#  988: 'AMS',
#  989: 'POP',
#  990: 'PopGen',
#  991: 'GenAlEx',
#  992: 'COMPERA',
#  993: 'R',
#  994: 'PCA',
#  995: 'GA',
#  996: 'CA',
#  997: 'PCA',
#  998: 'GA',
#  999: 'PCA',
#  ...}

# %% [markdown]
# Now, the software mentions within the dictionary do not contain empty spaces at the first position of the string. For the use of value_counts, the dictionary is converted to a pandas series.

# %%
software_series = pd.Series(software_dict)
software_series.value_counts()
# Out:
# R                        10805
# SPSS                      9210
# GraphPad Prism            3986
# Excel                     3856
# BLAST                     3674
#                          ...
# Maldita                      1
# Loccioni                     1
# NetPlantGene Server          1
# Discover                     1
# GWAS Catalog REST API        1
# Length: 102725, dtype: int64

# %% [markdown]
# Due to the removing of empty spaces, the length of the dtype decreased. For the purpose of minimising the length of the dtype, all strings will be capitalized.

# %%
software_dict = software_series.to_dict()

# %%
def capitalize_mentions(dic):
    """ Function iterating a dictionary and capitalizing all strings.
    """
    for i in dic:
        dic[i] = dic[i].upper()
    return dic

# %%
software_dict = capitalize_mentions(software_dict)
software_dict
# Out:
# {0: 'GOOGLE STREET VIEW',
#  1: 'SEGG',
#  2: 'STATA',
#  3: 'IAMCEST',
#  4: 'SPSS',
#  5: 'R',
#  6: 'MASSARRAY TYPER ANALYZER',
#  7: 'WECHAT',
#  8: 'SPSS STATISTICS',
#  9: 'STATISTICAL PACKAGE FOR SOCIAL SCIENCES (SPSS)',
#  10: 'BD CBA',
#  11: 'STATA',
#  12: 'STATA',
#  13: 'STATACORP',
#  14: 'SPSS',
#  15: 'SPSS',
#  16: 'GENORM',
#  17: 'GRAPHPAD PRISM',
#  18: 'GRAPHPAD',
#  19: 'CELLRANGER',
#  20: 'R',
#  21: 'SEURAT',
#  22: 'GGPLOT2',
#  23: 'LINREGPCR',
#  24: 'GRAMA',
#  25: 'R PACKAGE EDGER',
#  26: 'R PACKAGE EDGER',
#  27: 'R PACKAGE EDGER',
#  28: 'STAR',
#  29: 'FASTQC',
#  30: 'R PACKAGE ALDEX2',
#  31: 'IMAGEJ',
#  32: 'PFALBAS',
#  33: 'SAM',
#  34: 'MORO PRAXIS',
#  35: 'MORO',
#  36: 'R2HC',
#  37: 'SINGAPOUR',
#  38: 'PRESET',
#  39: 'GOOGLE TRENDS (GT',
#  40: 'GT',
#  41: 'SINUS',
#  42: 'VICTIMES',
#  43: 'SPIROCALL',
#  44: 'LIBSVM',
#  45: 'MATLAB VOICEBOX',
#  46: 'OPENS',
#  47: 'MILE',
#  48: 'DP',
#  49: 'DP',
#  50: 'DSGVO',
#  51: 'IOS',
#  52: 'DSGVO',
#  53: 'PEPP',
#  54: 'PT',
#  55: 'DP',
#  56: '3T',
#  57: 'REDCAPBASED',
#  58: 'REDCAP',
#  59: 'RESEARCH ELECTRONIC DATA CAPTURE',
#  60: 'R',
#  61: 'DDCNN',
#  62: 'AR',
#  63: 'INCART',
#  64: 'CLSM',
#  65: 'MIT',
#  66: 'BIH',
#  67: 'SUP',
#  68: 'INCART',
#  69: 'CLSM',
#  70: 'CLSM',
#  71: 'INCART',
#  72: 'ADAM',
#  73: 'SOMTE',
#  74: 'SMOTE',
#  75: 'SMOTE',
#  76: 'CLSM',
#  77: 'INCART',
#  78: 'CLSM',
#  79: 'CLSM',
#  80: 'INCART',
#  81: 'CLSM',
#  82: 'CLSM',
#  83: 'SPSS',
#  84: 'SPSS',
#  85: 'CT SCAN',
#  86: 'NCCS',
#  87: 'GRAPHPAD PRISM',
#  88: 'GRAPHPAD',
#  89: 'ZEN ZEISS',
#  90: 'FLOWJO',
#  91: 'ZEN ZEISS',
#  92: 'MCT',
#  93: 'RIBO',
#  94: 'RIBO',
#  95: 'RIBO',
#  96: 'SEQ',
#  97: 'RANDOM FOREST',
#  98: 'LOOCV',
#  99: 'BRANCH',
#  100: 'HDP',
#  101: 'MBRANCH',
#  102: 'LAMP',
#  103: 'NEAR',
#  104: 'LAMP',
#  105: 'NEAR',
#  106: 'GISAID',
#  107: 'MAFFT',
#  108: 'BIOEDIT',
#  109: 'SWISSMODEL',
#  110: 'HHPRED',
#  111: 'MEME',
#  112: 'MUTANT2',
#  113: 'TMHMM',
#  114: 'PROTTER',
#  115: 'SWISSMODEL',
#  116: 'HHPRED',
#  117: 'JPRED',
#  118: 'IQ',
#  119: 'TREE',
#  120: 'IQ',
#  121: 'TREE',
#  122: 'ACS',
#  123: 'GISAID',
#  124: 'PY',
#  125: 'MOL',
#  126: 'JPRED',
#  127: 'TMHMM',
#  128: 'PROTTER',
#  129: 'TASSER',
#  130: 'TASSER',
#  131: 'ADAPTIVE EVOLUTION SERVER',
#  132: 'DECNEO',
#  133: 'DECNEO',
#  134: 'NUMPY',
#  135: 'SCIPY',
#  136: 'PANDAS',
#  137: 'SCIKIT',
#  138: 'LEARN',
#  139: 'MATPLOTLIB',
#  140: 'PYIOMICA',
#  141: 'METASCAPE',
#  142: 'PYPI',
#  143: 'DECNEO',
#  144: 'DECNEO',
#  145: 'CELLRANGER',
#  146: 'METASCAPE',
#  147: 'PANGLAODB',
#  148: 'R',
#  149: 'GRAVITY',
#  150: 'METASCAPE',
#  151: 'DECNEO',
#  152: 'ALONA',
#  153: 'DECNEO',
#  154: 'CELLRANGER',
#  155: 'DECNEO',
#  156: 'DECNEO',
#  157: 'DECNEO',
#  158: 'METASCAPE',
#  159: 'DECNEO (DENDROGRAM OF CO - EXPRESSION WITH EVOLUTIONARY CONSERVATION AND NETWORK ENRICHMENT ORDERING)',
#  160: 'DECNEO',
#  161: 'SNOWMASS',
#  162: 'METASCAPE',
#  163: 'SPSS',
#  164: 'ENSEMBL',
#  165: 'BIOMART',
#  166: 'REVIGO',
#  167: 'CYTOSCAPE',
#  168: 'CYTOSCAPE',
#  169: 'CLUEGO',
#  170: 'REVIGO',
#  171: 'VETSCAN',
#  172: 'REVIGO',
#  173: 'CYTOSCAPE',
#  174: 'REVIGO',
#  175: 'SIMREL',
#  176: 'CYTOSCAPE',
#  177: 'CLUEGO',
#  178: 'GRAPHPAD PRISM',
#  179: 'GRAPHPAD PRISM',
#  180: 'QSR NVIVO',
#  181: 'ENGAGE',
#  182: 'SPSS',
#  183: 'R',
#  184: 'R FOUNDATION FOR STATISTICAL',
#  185: 'SAS',
#  186: 'STATA',
#  187: 'CONEVAL',
#  188: 'CUREVAC',
#  189: 'STATA MP15',
#  190: 'PROLISA',
#  191: 'BLOOD SUGAR LOUNGE',
#  192: 'COVIDX',
#  193: 'NET',
#  194: 'INCEPTION',
#  195: 'INCEPTIONV3',
#  196: 'XCEPTION',
#  197: 'MOBILENETV2',
#  198: 'XCEPTIONNET',
#  199: 'GITHUB',
#  200: 'GOOGLE SCHOLAR',
#  201: 'PAR',
#  202: 'PAR',
#  203: 'ENT',
#  204: 'QOL',
#  205: 'PAR',
#  206: 'QOL',
#  207: 'PAR',
#  208: 'ENT',
#  209: 'QOL',
#  210: 'AUDIAL',
#  211: 'SEMANTIC ANNOTATOR FOR INKSCAPE (SAI)',
#  212: 'AUDIAL',
#  213: 'AUDIAL',
#  214: 'AUDIAL',
#  215: 'AUDIAL',
#  216: 'AUDIAL',
#  217: 'AUDIAL',
#  218: 'AUDIAL',
#  219: 'AUDIAL',
#  220: 'AUDIAL',
#  221: 'AUDIAL',
#  222: 'AUDIAL',
#  223: 'AUDIAL',
#  224: 'AUDIAL',
#  225: 'AUDIAL',
#  226: 'AUDIAL',
#  227: 'AUDIAL (ACCESSIBLE UNIVERSAL DIAGRAMS THROUGH LANGUAGE)',
#  228: 'AUDIAL',
#  229: 'AUDIAL',
#  230: 'AUDIAL',
#  231: 'AUDIAL',
#  232: 'AUDIAL',
#  233: 'AUDIAL',
#  234: 'AUDIAL (ACCESSIBLE UNIVERSAL DIAGRAMS THROUGH LANGUAGE)',
#  235: 'AUDIAL',
#  236: 'AUDIAL',
#  237: 'AUDIAL',
#  238: 'AUDIAL',
#  239: 'TCGA2STAT',
#  240: 'SSL',
#  241: 'NETDX',
#  242: 'IDRW',
#  243: 'IDRW',
#  244: 'NETDX',
#  245: 'IDRW',
#  246: 'NETDX',
#  247: 'IDRW',
#  248: 'OMICSBIND',
#  249: 'NETDX',
#  250: 'IDRW',
#  251: 'IDRW',
#  252: 'NETDX',
#  253: 'IDRW',
#  254: 'NETDX',
#  255: 'IDRW',
#  256: 'IDRW',
#  257: 'TOPPGENET',
#  258: 'OMICSBIND',
#  259: 'TCGA2STAT',
#  260: 'IDRW',
#  261: 'NETDX',
#  262: 'SSL OMICS',
#  263: 'SSL OMICS',
#  264: 'IDRW',
#  265: 'NETDX',
#  266: 'SSL',
#  267: 'GRAPH',
#  268: '- PAD PRIZM',
#  269: 'GRAPH',
#  270: '- PAD',
#  271: 'GENSCRIPT',
#  272: 'SPSS STATISTICS',
#  273: 'NEWS',
#  274: 'ORIGINAL',
#  275: 'XPRIZE',
#  276: 'XPRIZE',
#  277: 'CODATA',
#  278: 'XPRIZE',
#  279: 'XPRIZE PANDEMIC',
#  280: 'XPRIZE',
#  281: 'IDEA BUILDER',
#  282: 'OPEN COVID PLEDGE',
#  283: 'CODATA',
#  284: 'OSMS',
#  285: 'XPRIZE',
#  286: 'CODATA',
#  287: 'ACCORD',
#  288: 'INGSA',
#  289: 'XPRIZE',
#  290: 'UBER',
#  291: 'CODATA',
#  292: 'COVID COMMONS',
#  293: 'RESOLVE',
#  294: 'OSMS',
#  295: 'XPRIZE',
#  296: 'XPRIZE',
#  297: 'GRAPHPAD PRISM',
#  298: 'GRAPHPAD',
#  299: 'LNRE',
#  300: 'LNRE',
#  301: 'LNRE',
#  302: 'TE',
#  303: 'REALPOLITIK',
#  304: 'GOOGLE SCHOLAR',
#  305: 'SPSS STATISTICS',
#  306: 'PRISM',
#  307: 'GRAPHPAD',
#  308: 'RECOVERY',
#  309: 'DANTEC',
#  310: 'DYNAM',
#  311: 'ICSTUDIO',
#  312: 'QUANTASOFT',
#  313: 'SPAR',
#  314: 'SPAR',
#  315: 'JEE',
#  316: 'JEE',
#  317: 'COCHRANE',
#  318: 'REVIEW MANAGER',
#  319: 'COCHRANE',
#  320: 'REVIEW MANAGER',
#  321: 'PRISMA',
#  322: 'VITAL',
#  323: 'VITAL',
#  324: 'MODBUS',
#  325: 'XAI',
#  326: 'VITAL',
#  327: 'VITAL',
#  328: 'VITAL',
#  329: 'SWAMP',
#  330: 'VITAL',
#  331: 'CENOTE',
#  332: 'SPSS',
#  333: 'SPSS',
#  334: 'SPSS STATISTICS',
#  335: 'ORACLE',
#  336: 'SPSS STATISTICS',
#  337: 'ANOSIM',
#  338: 'OPTICLUST',
#  339: 'CANOCO',
#  340: 'ANALYSIS OF SIMILARITY (ANOSIM)',
#  341: 'GEN',
#  342: 'ALEX',
#  343: 'ANOSIM',
#  344: 'MOTHUR',
#  345: 'MOTHUR',
#  346: 'UNIFRAC',
#  347: 'MOTHUR',
#  348: 'LEFSE',
#  349: 'PSORT',
#  350: 'PSORT',
#  351: 'SPSS',
#  352: 'ETAT',
#  353: 'ETAT',
#  354: 'PRISM',
#  355: 'FV',
#  356: 'FORREST',
#  357: 'STATA',
#  358: 'MENDELEY DESKTOP',
#  359: 'STATA',
#  360: 'EXCEL',
#  361: 'ENDNOTE',
#  362: 'SCOPUS',
#  363: 'SCPL',
#  364: 'DGGRL',
#  365: 'ANOSIM',
#  366: 'R',
#  367: 'EXCEL',
#  368: 'SPSS',
#  369: 'ECVIM',
#  370: 'GENOME ANALYSIS TOOLKIT',
#  371: 'SUPERSAT',
#  372: 'ACVIM',
#  373: 'XSTRAIN',
#  374: 'BURDICK HOLTER ANALYSIS',
#  375: 'PRISM7',
#  376: 'IMMTT4',
#  377: 'CATAT4',
#  378: 'GRAPHPAD PRISM',
#  379: 'SIGMAPLOT',
#  380: 'SYSTAT',
#  381: 'NSIP',
#  382: 'PROMED',
#  383: 'MAIL',
#  384: 'FLUNET',
#  385: 'FLUID',
#  386: 'DOCS',
#  387: 'GPHIN',
#  388: 'GOARN',
#  389: 'GOARN',
#  390: 'GOARN',
#  391: 'PROMED',
#  392: 'MAIL',
#  393: 'GRAPHPAD PRISM',
#  394: 'GRAPHPAD PRISM',
#  395: 'GRECCAR2',
#  396: 'STENT',
#  397: 'IDEAL',
#  398: 'GRECCAR',
#  399: 'GRECCAR2',
#  400: 'GRECCAR',
#  401: 'SMARTPLS',
#  402: 'KAKAOTALK',
#  403: 'SPSS STATISTICS',
#  404: 'SMART PLS',
#  405: 'GOOGLE DRIVE',
#  406: 'KAKAOTALK',
#  407: 'IMAGEJ',
#  408: 'SPSS',
#  409: 'QBASE',
#  410: 'IMAGE J',
#  411: 'GENORM',
#  412: 'UFIBRO',
#  413: 'IMAGEJ',
#  414: 'REDCAP',
#  415: 'RESEARCH ELECTRONIC DATA CAPTURE (REDCAP)',
#  416: 'REDCAP',
#  417: 'NAVIGATOR NETWORK NET',
#  418: 'NTS',
#  419: 'NET',
#  420: 'TENSORFLOW',
#  421: 'DEEPLIFT',
#  422: 'DEEPLIFT',
#  423: 'DANN',
#  424: 'SANN',
#  425: 'R',
#  426: 'RSTUDIO',
#  427: 'R',
#  428: 'R',
#  429: 'WHATSAPP TM',
#  430: 'REDCAP',
#  431: 'MFOLD',
#  432: 'MFOLD',
#  433: 'MFOLD',
#  434: 'MFOLD',
#  435: 'MFOLD',
#  436: 'OPEN',
#  437: 'OPEN SCIENCE',
#  438: 'OPEN',
#  439: 'CO',
#  440: 'CIN',
#  441: 'CORD',
#  442: 'GENSIM',
#  443: 'VOSVIEWER',
#  444: 'VOSVIEWER',
#  445: 'SCISPACY',
#  446: 'VOSVIEWER',
#  447: 'ALTMETRIC',
#  448: 'DIMENSIONS',
#  449: 'WOS',
#  450: 'STRICT',
#  451: 'ALTMETRIC',
#  452: 'DIMENSIONS',
#  453: 'ALTMETRIC',
#  454: 'ALTMETRIC',
#  455: 'ALTMETRIC',
#  456: 'PMC',
#  457: 'VOSVIEWER',
#  458: 'ALTMETRIC',
#  459: 'EXCEL',
#  460: 'EPI',
#  461: 'INFO',
#  462: 'SAS',
#  463: 'SAS',
#  464: 'SPSS',
#  465: 'SPSS',
#  466: 'FLOW',
#  467: 'STATA',
#  468: 'GRAPHPAD PRISM',
#  469: 'REVIEW MANAGER',
#  470: 'ADAM',
#  471: 'FASTTEXT',
#  472: 'ELMO',
#  473: 'SKYPE',
#  474: 'FACETIME',
#  475: 'MESH',
#  476: 'MEDLINE',
#  477: 'KAON',
#  478: 'KAON',
#  479: 'HEADACHE',
#  480: 'KAON',
#  481: 'KAON',
#  482: 'KAON',
#  483: 'KAON',
#  484: 'MEDLINE',
#  485: 'MEDLINE',
#  486: 'KAON',
#  487: 'GPC',
#  488: 'GPC',
#  489: 'MATLAB',
#  490: 'MATLAB',
#  491: 'NL ACTIEF',
#  492: 'EXCEL',
#  493: 'EXCEL',
#  494: 'OPTIMAS',
#  495: 'OPTIMAST',
#  496: 'SPSS',
#  497: 'SPSS',
#  498: 'EXCEL',
#  499: 'VMD',
#  500: 'GNUPLOT',
#  501: 'PRODY',
#  502: 'SPSS',
#  503: 'CONSORT',
#  504: 'FILEMAKER PRO',
#  505: 'ANALYSIS',
#  506: 'STATA',
#  507: 'BIACORE',
#  508: 'MEGA',
#  509: 'ERISK',
#  510: 'REDDIT',
#  511: 'ERISK',
#  512: 'LINGUISTIC INQUIRY AND WORD COUNT LIWC',
#  513: 'LIWC',
#  514: 'REDDIT',
#  515: 'LIWC',
#  516: 'EARLY RISK PREDICTION ON INTERNET (ERISK) LINGUISTICS AND CLINICAL PSYCHOLOGY (CLPSYCH)',
#  517: 'ERISK',
#  518: 'WORLDOMETERS',
#  519: 'SMARTPLS',
#  520: 'COVID ANALYTICS',
#  521: 'PYTORCH',
#  522: 'MOCO',
#  523: 'AI',
#  524: 'SEGMENT',
#  525: 'RESNET50',
#  526: 'AI',
#  527: '3D',
#  528: 'SLICER',
#  529: 'MOCO',
#  530: 'SPYD',
#  531: 'SOMATOM DRIVE',
#  532: 'DISCOVERY',
#  533: 'OPTIMA',
#  534: 'SPYD',
#  535: 'PANDAS',
#  536: 'SCIKIT',
#  537: 'LEARN',
#  538: 'AI',
#  539: 'SEGMENT',
#  540: 'MOCO',
#  541: 'FACETIME',
#  542: 'IMAGEJ',
#  543: 'IMAGEJ',
#  544: 'GRAPHPAD PRISM',
#  545: 'SRDFDS',
#  546: 'MATLAB',
#  547: 'IDEFO',
#  548: 'MATLAB',
#  549: 'SIUH',
#  550: 'VERIZON',
#  551: 'SUNRISE CLINICAL MANAGER',
#  552: 'SPSS',
#  553: 'SPSS PROCESS MACRO',
#  554: 'FEDORA',
#  555: 'UROSOME',
#  556: 'SURVEY MONKEY',
#  557: 'WOLFRAM MATHEMATICA',
#  558: 'MAT',
#  559: 'MATLAB',
#  560: 'GOOGLE SCHOLAR',
#  561: 'CASMIM',
#  562: 'CASMIM',
#  563: 'CASMIM',
#  564: 'CASMIM',
#  565: 'DATACOLOR',
#  566: 'WINMATCH',
#  567: 'SEDFIT',
#  568: 'SEDPHAT',
#  569: 'SEDNTERP',
#  570: 'CLAMPFIT',
#  571: 'PERSAL',
#  572: 'PERSAL',
#  573: 'MEDSCAPE',
#  574: 'GOOGLE SCHOLAR',
#  575: 'GOOGLE SCHOLAR',
#  576: 'XPERT XPRESS',
#  577: 'GENEXPERT',
#  578: 'EP',
#  579: 'EXCEL',
#  580: 'ID NOW',
#  581: 'XPERT XPRESS',
#  582: 'COBAS',
#  583: 'CEPHEID',
#  584: 'XPERT XPRESS',
#  585: 'SIMPLEXA',
#  586: 'PYTHON',
#  587: 'SKLEARN',
#  588: 'NUMPY',
#  589: 'PANDAS',
#  590: 'SCIPY',
#  591: 'COVID DATA SAVE LIVES',
#  592: 'SUPER',
#  593: 'SUPER',
#  594: 'SUPER',
#  595: 'SUPER',
#  596: 'SUPER',
#  597: 'SUPER',
#  598: 'SUPER',
#  599: 'INFERNAL',
#  600: 'BWA',
#  601: 'SUPER',
#  602: 'SUPER (POSITION EXPLORATION WITH',
#  603: 'SUPER',
#  604: 'HISAT2',
#  605: 'SUPER',
#  606: 'SUPER',
#  607: 'MUSCLE',
#  608: 'FASTTREE',
#  609: 'SUPER',
#  610: 'SUPER (SUBGENOMIC MRNA POSITION EXPLORATION WITH RNA - SEQUENCING)',
#  611: 'SUPER',
#  612: 'RDP4',
#  613: 'SUPER',
#  614: 'VARNA',
#  615: 'SUPER',
#  616: 'SUPER',
#  617: 'SUPER',
#  618: 'SUPER',
#  619: 'SUPER',
#  620: 'SUPER',
#  621: 'SUPER',
#  622: 'SUPER',
#  623: 'SUPER',
#  624: 'SUPER',
#  625: 'MUSCLE',
#  626: 'MASH',
#  627: 'RDP4',
#  628: 'SIMPLOT',
#  629: 'RDP4',
#  630: 'INFERNAL',
#  631: 'SUPER',
#  632: 'EXPLORYS',
#  633: 'EXPLORYS',
#  634: 'EXPLORYS EXPLORE COHORT DISCOVERY',
#  635: 'EXPLORYS',
#  636: 'WATSON HEALTH EXPLORYS',
#  637: 'EXPLORYS COHORT DISCOVERY',
#  638: 'EXPLORYS',
#  639: 'SNOMED',
#  640: 'CT',
#  641: 'EXPLORYS',
#  642: 'SNOMED',
#  643: 'CT',
#  644: 'SNOMED',
#  645: 'CT',
#  646: 'EXPLORYS',
#  647: 'ESE FINDER',
#  648: 'ESR SEARCH',
#  649: 'EMBL',
#  650: 'RBPMAP',
#  651: 'RBPMAP',
#  652: 'ESEFINDER',
#  653: 'KINETIC',
#  654: 'LIGAND',
#  655: 'SCATCBARD',
#  656: 'LIGAND',
#  657: 'CODIESP',
#  658: 'CODIESP',
#  659: 'CODIESP',
#  660: 'CLEF',
#  661: 'CODIESP',
#  662: 'CLEF',
#  663: 'CODIESP',
#  664: 'CODIESP',
#  665: 'CODIESP',
#  666: 'CODIESP',
#  667: 'CODIESP',
#  668: 'CODIESP',
#  669: 'CODIESP',
#  670: 'CLEF',
#  671: 'CLEF',
#  672: 'COMMONCRAWL',
#  673: 'FOLDX',
#  674: 'ADAR',
#  675: 'R',
#  676: 'R',
#  677: 'PYSAM',
#  678: 'CIRSEQ',
#  679: 'R',
#  680: 'CIRSEQ',
#  681: 'CIRSEQ',
#  682: 'PYMOL',
#  683: 'PYMOL',
#  684: 'ADAR',
#  685: 'R',
#  686: 'GGSEQLOGO',
#  687: 'CIRSEQ',
#  688: 'CIRSEQ',
#  689: 'FITNESSESTIMATOR',
#  690: 'CIRSEQ',
#  691: 'CIRSEQ',
#  692: 'R',
#  693: 'ATOGORTTOC',
#  694: 'USINGPYSAM',
#  695: 'PY',
#  696: 'CIRSEQ',
#  697: 'CIRSEQ',
#  698: 'MULTIMATCH',
#  699: 'GENESCRIPT',
#  700: 'R',
#  701: 'MAXIMUMLIKELIHOODESTIMATION _ Q20 _ ZACH R',
#  702: 'MODELER',
#  703: 'FITNESSESTIMATOR',
#  704: 'CIRSEQ',
#  705: 'IMAGEJ',
#  706: 'STEPONE',
#  707: 'IMAGEJ',
#  708: 'PRIMER EXPLORER',
#  709: 'MEGABLAST',
#  710: 'EULAR',
#  711: 'EFE VERIFICA',
#  712: 'POLITIFACT',
#  713: 'POLITIFACT',
#  714: 'LEADSTORIES',
#  715: 'POLITIFACT',
#  716: 'SNOPES',
#  717: 'EFE VERIFICA',
#  718: 'POLITIFACT',
#  719: 'POLITIFACT',
#  720: 'POLITIFACT',
#  721: 'MINIVER',
#  722: 'JCDATRASTO',
#  723: 'POLITIFACT',
#  724: 'POLITIFACT - - METER',
#  725: 'POLITI',
#  726: 'FACT',
#  727: 'POLITIFACT',
#  728: 'EUROMOMO',
#  729: 'MINIVER',
#  730: 'POLITIFACT',
#  731: 'LEAD',
#  732: 'POLITIFACT',
#  733: 'LEADSTORIES',
#  734: 'MNGS',
#  735: 'MEGALIGN',
#  736: 'MEGALIGN',
#  737: 'CLUSTAL W',
#  738: 'MEGALIGN',
#  739: 'BLAST',
#  740: 'LEICA MICROSYSTEMS (LAS AF)',
#  741: 'LEICA MICROSYSTEMS (LAS AF)',
#  742: 'NIH IMAGE - J',
#  743: 'MACRO®',
#  744: 'STATA',
#  745: 'COARTHA',
#  746: 'MACRO®',
#  747: 'ROSETTA',
#  748: 'ENRICH',
#  749: 'CUSPARSE',
#  750: 'NAST3DGP',
#  751: 'ARPACK',
#  752: 'PETSC',
#  753: 'EIGEN',
#  754: 'SPARSPAK',
#  755: 'CUSPARSE',
#  756: 'FREE SOFTWARE',
#  757: 'GERRIS FLOW SOLVER',
#  758: 'ENSE',
#  759: 'OPLS',
#  760: 'DA',
#  761: 'OPLS',
#  762: 'DA',
#  763: 'STATA',
#  764: 'DOVEPRESS',
#  765: 'SURVEY MONKEY',
#  766: 'HISAT2',
#  767: 'GOATOOLS',
#  768: 'TRINITY',
#  769: 'LME4',
#  770: 'SARTOOLS',
#  771: 'ENSEMBL',
#  772: 'BUSCO',
#  773: 'FASTQC',
#  774: 'DESEQ2',
#  775: 'EDGER',
#  776: 'SARTOOLS',
#  777: 'EDGER',
#  778: 'ENSEMBL',
#  779: 'RNAMMER',
#  780: 'RSEM',
#  781: 'ENSEMBL',
#  782: 'GOATOOLS',
#  783: 'FEATURECOUNTS',
#  784: 'TRIMMOMATIC',
#  785: 'DESEQ2',
#  786: 'EDGER',
#  787: 'GOATOOLS',
#  788: 'GOATOOLS',
#  789: 'SARTOOLS',
#  790: 'BLAST',
#  791: 'BOWTIE',
#  792: 'RSEM',
#  793: 'FEATURECOUNTS',
#  794: 'JPRED4',
#  795: 'MEGA',
#  796: 'MEME',
#  797: 'DATAMONKEY',
#  798: 'JPRED4',
#  799: 'SEQUENCHER',
#  800: 'KNOWLEDGE EDUCATION',
#  801: 'MED',
#  802: 'STUD',
#  803: 'LIMESURVEY',
#  804: 'SPSS STATISTICS',
#  805: 'WEBEX MEETING',
#  806: 'SMARTPLS3',
#  807: 'SMART PLS',
#  808: 'R',
#  809: 'R FOUNDATION FOR STATISTICAL COMPUTING',
#  810: 'GRAPHPAD',
#  811: 'PRISM',
#  812: 'IMAGEJ',
#  813: 'COOT',
#  814: 'REFMAC',
#  815: 'GRAPHPAD',
#  816: 'PHASER',
#  817: 'XDS',
#  818: 'SCALA',
#  819: 'CCP4 SUITE',
#  820: 'VSD',
#  821: 'SIMCA',
#  822: 'SPSS',
#  823: 'DA',
#  824: 'OLINK',
#  825: 'GENEIOUS PRIME',
#  826: 'GENEIOUS PRIME',
#  827: 'JITAIS',
#  828: 'SCOPUS',
#  829: 'PORTACOUNT',
#  830: 'PORTACOUNT',
#  831: 'BITREX',
#  832: 'CLINGEN',
#  833: 'ACMG',
#  834: 'AMP',
#  835: 'LMNA',
#  836: 'SITEENGINE',
#  837: 'SITEENGINE',
#  838: 'MULTIPROT',
#  839: 'SITEENGINE',
#  840: 'SITEENGINE',
#  841: 'SITEENGINE',
#  842: 'SITEENGINE',
#  843: 'SITEENGINE',
#  844: 'SITEENGINE',
#  845: 'SITEENGINE',
#  846: 'SITEENGINE',
#  847: 'SITEENGINE',
#  848: 'SITEENGINE',
#  849: 'SITEENGINE',
#  850: 'SITEENGINE',
#  851: 'SITEENGINE',
#  852: 'SITEENGINE',
#  853: 'SITEENGINE',
#  854: 'SITEENGINE',
#  855: 'SITEENGINE',
#  856: 'SITEENGINE',
#  857: 'SITEENGINE',
#  858: 'SITEENGINE',
#  859: 'SITEENGINE',
#  860: 'SITEENGINE',
#  861: 'SITEENGINE',
#  862: 'SITEENGINE',
#  863: 'SITEENGINE',
#  864: 'RELIBASE',
#  865: 'SITEENGINE',
#  866: 'MULTIPROT',
#  867: 'SITEENGINE',
#  868: 'SITEENGINE',
#  869: 'SITEENGINE',
#  870: 'SITEENGINE',
#  871: 'SITEENGINE',
#  872: 'SITEENGINE',
#  873: 'SITEENGINE',
#  874: 'JESS',
#  875: 'CASTP',
#  876: 'SITEENGINE',
#  877: 'SITEENGINE',
#  878: 'SITEENGINE',
#  879: 'SITEENGINE',
#  880: 'SITEENGINE',
#  881: 'JMP',
#  882: 'SAS',
#  883: 'SAMTOOLS',
#  884: 'BOWTIE',
#  885: 'GRAPHPAD PRISM',
#  886: 'FLOWJO',
#  887: 'GRAPHPAD PRISM',
#  888: 'MESHFIX',
#  889: 'SAS',
#  890: 'MIRPATH',
#  891: 'DIANA',
#  892: 'CLUSTER',
#  893: 'JAVA TREEVIEW',
#  894: 'MIRECORDS',
#  895: 'MIRANDA',
#  896: 'MIR2DISEASE',
#  897: 'PHENOMIR',
#  898: 'SM2MIR',
#  899: 'PHARMACOMIREPIMIR',
#  900: 'SDS',
#  901: 'STATA',
#  902: 'SPSS',
#  903: 'ZETAGENE',
#  904: 'FACTOEXTRA R',
#  905: 'GRAPHPAD PRISM',
#  906: 'POLYPHEN',
#  907: 'CDNN',
#  908: 'SOAP',
#  909: 'ANTIGEN',
#  910: 'PSIGNAL',
#  911: 'PCGENE PACKAGE',
#  912: 'PSEARCH',
#  913: 'COIL',
#  914: 'CLUSTAL',
#  915: 'INTELLIGENETICS',
#  916: 'COIL',
#  917: 'SOAP',
#  918: 'PCGENE',
#  919: 'COIL',
#  920: 'STATA',
#  921: 'COCHRANE RISK OF BIAS TOOL',
#  922: 'OVID MEDLINE',
#  923: 'ENDNOTE X9',
#  924: 'AUTOMOTIFSERVER',
#  925: 'GPS',
#  926: 'KINASEPHOS',
#  927: 'NETPHOSK',
#  928: 'PPSP',
#  929: 'PREDPHOSPHOSCANSITE',
#  930: 'META PREDICTOR',
#  931: 'SULFINATOR',
#  932: 'PPSP',
#  933: 'NETPHOSK',
#  934: 'PREDPHOSPHO',
#  935: 'NETPHOSK',
#  936: 'AMS3',
#  937: 'PTM',
#  938: 'ARCHIVE',
#  939: 'KINASEPHOS',
#  940: 'SEQUENCE GENERATOR',
#  941: 'PREDICTOR',
#  942: 'PREDICTOR',
#  943: 'AUTOMOTIFSERVER (AMS)',
#  944: 'AMS',
#  945: 'MS',
#  946: 'EXCEL',
#  947: 'LOOCV',
#  948: 'NETPHOS',
#  949: 'NETPHOSK',
#  950: 'PHOSPHO',
#  951: 'ELM',
#  952: 'NETPHOSK',
#  953: 'NETPHOSK',
#  954: 'NETPHOSK',
#  955: 'SCANSITE',
#  956: 'NETPHOS',
#  957: 'NET',
#  958: 'PHOSK',
#  959: 'NETOGLYC',
#  960: 'NETNGLYC',
#  961: 'DICTYOGLYC',
#  962: 'YINOYANG',
#  963: 'AMS',
#  964: 'AMS',
#  965: 'PREDICTOR',
#  966: 'NETPHOSK',
#  967: 'AMS',
#  968: 'META PREDICTOR',
#  969: 'AMS3',
#  970: 'AMS',
#  971: 'AMS',
#  972: 'AMS3',
#  973: 'PROSITE',
#  974: 'NETPHOSK',
#  975: 'AMS',
#  976: 'AUTOMOTIF SERVER',
#  977: 'AMS',
#  978: 'ELM',
#  979: 'NETPHOSK',
#  980: 'LINUX',
#  981: 'LOOCV',
#  982: 'PHOSITE',
#  983: 'KINASEPHOS',
#  984: 'NETPHOSK',
#  985: 'PREDPHOSPHO',
#  986: 'SCANSITE',
#  987: 'APACHE',
#  988: 'AMS',
#  989: 'POP',
#  990: 'POPGEN',
#  991: 'GENALEX',
#  992: 'COMPERA',
#  993: 'R',
#  994: 'PCA',
#  995: 'GA',
#  996: 'CA',
#  997: 'PCA',
#  998: 'GA',
#  999: 'PCA',
#  ...}

# %%
software_series = pd.Series(software_dict)
software_series = software_series.value_counts()
software_series
# Out:
# R                 10805
# SPSS               9229
# GRAPHPAD PRISM     4461
# EXCEL              4054
# BLAST              3943
#                   ...
# SENOVA                1
# WSOLVE                1
# GOSE                  1
# MSCARLET              1
# ROBUSTALERT           1
# Length: 89482, dtype: int64

# %% [markdown]
# Due to the capitalization of software mentions, the length of the dytpe could be decreased. Subsequently, the fuzzywuzzy compare algorithm will be introduced. This algorithm is based on Levenshtein which checks the similarity of strings by various aspects.

# %%
def fuzzy_ratio_compare(str1, str2, th):
    """ Function to compare to strings based on a given threeshold. 
    """
    ratio = fuzz.ratio(str1, str2)
    if(ratio > th):
        return True
    else:
        return False
    
def fuzzy_partial_ratio_compare(str1, str2, th):
    """ Function to compare to strings based on a given threeshold. 
    """
    ratio = fuzz.partial_ratio(str1, str2)
    if(ratio > th):
        return True
    else:
        return False
    
def fuzzy_token_sort_ratio_compare(str1, str2, th):
    """ Function to compare to strings based on a given threeshold. 
    """
    ratio = fuzz.token_sort_ratio(str1, str2)
    if(ratio > th):
        return True
    else:
        return False

def fuzzy_token_set_ratio_compare(str1, str2, th):
    """ Function to compare to strings based on a given threeshold. 
    """
    ratio = fuzz.token_set_ratio(str1, str2)
    if(ratio > th):
        return True
    else:
        return False

# %% [markdown]
# Due to performance reasons, further investigation will be conducted with a subset of the initial series based on the limit.

# %%
limit = 10000
software_series_shaped = software_series.head(limit)
software_series_shaped
# Out:
# R                 10805
# SPSS               9229
# GRAPHPAD PRISM     4461
# EXCEL              4054
# BLAST              3943
#                   ...
# GOCHECK               8
# OURA                  8
# EXONERATE             8
# TOUSANTICOVID         8
# DAL                   8
# Length: 10000, dtype: int64

# %% [markdown]
# Converting the series to a DataFrame for comparison purposes. The index of the DataFrame is required for selecting rows.

# %%
ts = software_series_shaped.to_frame()
list_soft = []
list_matches = [0]
for i in range(len(ts)):
    list_soft.append(software_series_shaped.index[i])
    list_matches.append(software_series_shaped[i])
df_shaped = pd.DataFrame()
df_shaped['Software'] = list_soft
df_shaped['Matches'] = list_matches[1:]
df_shaped
# Out:
#             Software  Matches
# 0                  R    10805
# 1               SPSS     9229
# 2     GRAPHPAD PRISM     4461
# 3              EXCEL     4054
# 4              BLAST     3943
# ...              ...      ...
# 9995         GOCHECK        8
# 9996            OURA        8
# 9997       EXONERATE        8
# 9998   TOUSANTICOVID        8
# 9999             DAL        8
#
# [10000 rows x 2 columns]

# %% [markdown]
# Replacing special characters to prevent unterminated subpattern at a later stage of this Notebook.

# %%
df_shaped['Software'] = df_shaped.Software.str.replace('(','')
df_shaped['Software'] = df_shaped.Software.str.replace(')','')

# %% [markdown]
# The following function compares software mentions based on the fuzzywuzzy method. As a result, a blacklist with identified duplicates and a modified dataframe are returned.

# %%
def unify_dataframe(df, th):
    """Match software mentions based on fuzzywuzzy algorithm
    """
    df_holder = df
    blacklist = set()
    for i in range(len(df)):
        for j in range(i + 1, len(df)):
            if df['Software'][i] not in blacklist:
                if(fuzzy_token_set_ratio_compare(df['Software'][i], df['Software'][j], th)):
                    print("'"+df['Software'][i]+"' with " + str(df['Matches'][i]) + " mentions matched with '" + df['Software'][j] + "' mentioned " + str(df['Matches'][j])+ " times")
                    df['Matches'][i] = int(df['Matches'][i] + df['Matches'][j])
                    blacklist.add(df['Software'][j])
    df_holder = df
    return df_holder, blacklist

# %%
# %%time
threeshold = 84
df_returned = unify_dataframe(df_shaped, threeshold)
df_unified = df_returned[0]
blacklist = df_returned[1]
#Wall time: 1h 4min 32s -> head = 10000 th -> 85
#Wall time: 17min 25s -> head = 5000 th -> 85
# Out:
# 'R' with 10805 mentions matched with 'R PACKAGE' mentioned 313 times
# 'R' with 11118 mentions matched with 'R FOUNDATION FOR STATISTICAL COMPUTING' mentioned 280 times
# 'R' with 11398 mentions matched with 'R CORE TEAM' mentioned 207 times
# 'R' with 11605 mentions matched with 'R STUDIO' mentioned 148 times
# 'R' with 11753 mentions matched with 'R DEVELOPMENT CORE TEAM' mentioned 86 times
# 'R' with 11839 mentions matched with 'R SCRIPT' mentioned 84 times
# 'R' with 11923 mentions matched with 'MASK R - CNN' mentioned 71 times
# 'R' with 11994 mentions matched with 'R FOUNDATION FOR STATISTICAL' mentioned 63 times
# 'R' with 12057 mentions matched with 'R CORE' mentioned 62 times
# <ipython-input-25-273964dd7c89>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Matches'][i] = int(df['Matches'][i] + df['Matches'][j])
# 'R' with 12119 mentions matched with 'R PROJECT FOR STATISTICAL COMPUTING' mentioned 57 times
# 'R' with 12176 mentions matched with 'R SCRIPTS' mentioned 55 times
# 'R' with 12231 mentions matched with 'R FOUNDATION FOR' mentioned 38 times
# 'R' with 12269 mentions matched with 'R SHINY' mentioned 36 times
# 'R' with 12305 mentions matched with 'R LANGUAGE' mentioned 34 times
# 'R' with 12339 mentions matched with 'R PACKAGES' mentioned 33 times
# 'R' with 12372 mentions matched with 'R FOR' mentioned 33 times
# 'R' with 12405 mentions matched with 'R ENVIRONMENT' mentioned 32 times
# 'R' with 12437 mentions matched with 'R PACKAGE LIMMA' mentioned 31 times
# 'R' with 12468 mentions matched with 'R FOUNDATION' mentioned 28 times
# 'R' with 12496 mentions matched with 'R PACKAGE SEURAT' mentioned 27 times
# 'R' with 12523 mentions matched with 'R PACKAGE "' mentioned 27 times
# 'R' with 12550 mentions matched with 'LIMMA R' mentioned 24 times
# 'R' with 12574 mentions matched with 'R PACKAGE GGPLOT2' mentioned 23 times
# 'R' with 12597 mentions matched with 'FASTER R - CNN' mentioned 22 times
# 'R' with 12619 mentions matched with 'R PACKAGE EPIESTIM' mentioned 21 times
# 'R' with 12640 mentions matched with 'SEURAT R PACKAGE' mentioned 20 times
# 'R' with 12660 mentions matched with 'R PACKAGE DESEQ2' mentioned 20 times
# 'R' with 12680 mentions matched with 'R COMMANDER' mentioned 20 times
# 'R' with 12700 mentions matched with 'R PACKAGE VEGAN' mentioned 19 times
# 'R' with 12719 mentions matched with 'R PACKAGE LME4' mentioned 17 times
# 'R' with 12736 mentions matched with 'R R DEVELOPMENT CORE TEAM' mentioned 16 times
# 'R' with 12752 mentions matched with 'R PACKAGE EDGER' mentioned 16 times
# 'R' with 12768 mentions matched with 'CLUSTERPROFILER R PACKAGE' mentioned 15 times
# 'R' with 12783 mentions matched with 'DESEQ2 R' mentioned 15 times
# 'R' with 12798 mentions matched with 'R PACKAGE CLUSTERPROFILER' mentioned 15 times
# 'R' with 12813 mentions matched with 'R SHINY APP' mentioned 14 times
# 'R' with 12827 mentions matched with 'R BIOCONDUCTOR' mentioned 14 times
# 'R' with 12841 mentions matched with 'R R CORE TEAM' mentioned 14 times
# 'R' with 12855 mentions matched with 'R DEVELOPMENT CORE' mentioned 14 times
# 'R' with 12869 mentions matched with 'SEURAT R' mentioned 13 times
# 'R' with 12882 mentions matched with 'LIMMA R PACKAGE' mentioned 13 times
# 'R' with 12895 mentions matched with 'R PACKAGE MASS' mentioned 12 times
# 'R' with 12907 mentions matched with 'MTCONNECT R' mentioned 12 times
# 'R' with 12919 mentions matched with 'EPIESTIM R' mentioned 12 times
# 'R' with 12931 mentions matched with 'MASK R CNN' mentioned 11 times
# 'R' with 12942 mentions matched with 'R PACKAGE PHEATMAP' mentioned 11 times
# 'R' with 12953 mentions matched with 'R STATS' mentioned 11 times
# 'R' with 12964 mentions matched with 'R PACKAGE STATS' mentioned 11 times
# 'R' with 12975 mentions matched with 'R PACKAGE APE' mentioned 11 times
# 'R' with 12986 mentions matched with 'R PACKAGE MGCV' mentioned 10 times
# 'R' with 12996 mentions matched with 'R PACKAGE GLMNET' mentioned 10 times
# 'R' with 13006 mentions matched with 'GOSEQ R PACKAGE' mentioned 10 times
# 'R' with 13016 mentions matched with 'R FOR STATISTICAL' mentioned 10 times
# 'R' with 13026 mentions matched with 'STATS R PACKAGE' mentioned 10 times
# 'R' with 13036 mentions matched with 'R R CORE' mentioned 10 times
# 'R' with 13046 mentions matched with 'LME4 R' mentioned 9 times
# 'R' with 13055 mentions matched with 'MATLAB R' mentioned 9 times
# 'R' with 13064 mentions matched with 'GGPLOT2 R' mentioned 9 times
# 'R' with 13073 mentions matched with 'DESEQ2 R PACKAGE' mentioned 9 times
# 'R' with 13082 mentions matched with 'EDGER R PACKAGE' mentioned 9 times
# 'R' with 13091 mentions matched with 'R LIBRARY' mentioned 9 times
# 'R' with 13100 mentions matched with 'R 0' mentioned 9 times
# 'R' with 13109 mentions matched with 'R R' mentioned 9 times
# 'R' with 13118 mentions matched with 'R PACKAGE META' mentioned 9 times
# 'R' with 13127 mentions matched with 'R PROJECT' mentioned 9 times
# 'R' with 13136 mentions matched with 'R PACKAGE IGRAPH' mentioned 9 times
# 'R' with 13145 mentions matched with 'WGCNA R PACKAGE' mentioned 9 times
# 'R' with 13154 mentions matched with 'R PACKAGE GGTREE' mentioned 9 times
# 'R' with 13163 mentions matched with 'CASCADE R - CNN' mentioned 8 times
# 'R' with 13171 mentions matched with 'R PACKAGE SURVIVAL' mentioned 8 times
# 'R' with 13179 mentions matched with 'GGPLOT2 R PACKAGE' mentioned 8 times
# 'SPSS' with 9229 mentions matched with 'SPSS STATISTICS' mentioned 1233 times
# 'SPSS' with 10462 mentions matched with 'STATISTICAL PACKAGE FOR THE SOCIAL SCIENCES SPSS' mentioned 207 times
# 'SPSS' with 10669 mentions matched with 'STATISTICAL PACKAGE FOR SOCIAL SCIENCES SPSS' mentioned 170 times
# 'SPSS' with 10839 mentions matched with 'STATISTICAL PACKAGE FOR THE SOCIAL SCIENCES SPSS' mentioned 91 times
# 'SPSS' with 10930 mentions matched with 'STATISTICAL PACKAGE FOR SOCIAL SCIENCE SPSS' mentioned 61 times
# 'SPSS' with 10991 mentions matched with 'STATISTICAL PACKAGE FOR SOCIAL SCIENCES SPSS' mentioned 56 times
# 'SPSS' with 11047 mentions matched with 'SPSS®' mentioned 42 times
# 'SPSS' with 11089 mentions matched with 'SPSS STATISTICAL PACKAGE FOR THE SOCIAL SCIENCES' mentioned 41 times
# 'SPSS' with 11130 mentions matched with 'SPSS AMOS' mentioned 31 times
# 'SPSS' with 11161 mentions matched with 'STATISTICAL PRODUCT AND SERVICE SOLUTIONS SPSS' mentioned 24 times
# 'SPSS' with 11185 mentions matched with 'SPSS STATISTIC' mentioned 21 times
# 'SPSS' with 11206 mentions matched with 'SPSS® STATISTICS' mentioned 19 times
# 'SPSS' with 11225 mentions matched with 'SPSS STATISTICAL PACKAGE FOR SOCIAL SCIENCES' mentioned 16 times
# 'SPSS' with 11241 mentions matched with 'STATISTICAL PACKAGE FOR SOCIAL SCIENCE SPSS' mentioned 14 times
# 'SPSS' with 11255 mentions matched with 'SPSS PROCESS' mentioned 14 times
# 'SPSS' with 11269 mentions matched with 'STATISTICAL PACKAGE FOR THE SOCIAL SCIENCE SPSS' mentioned 12 times
# 'SPSS' with 11281 mentions matched with 'SPASS' mentioned 9 times
# 'SPSS' with 11290 mentions matched with 'STATISTICAL PROGRAM FOR SOCIAL SCIENCES SPSS' mentioned 8 times
# 'SPSS' with 11298 mentions matched with 'SPSS STATISTICAL PACKAGE FOR SOCIAL SCIENCE' mentioned 8 times
# 'SPSS' with 11306 mentions matched with 'STATISTICAL PACKAGE FOR THE SOCIAL SCIENCES SOFTWARE SPSS' mentioned 8 times
# 'SPSS' with 11314 mentions matched with 'SPSS STATISTICAL PACKAGE FOR THE SOCIAL SCIENCES' mentioned 8 times
# 'GRAPHPAD PRISM' with 4461 mentions matched with 'GRAPHPAD' mentioned 2278 times
# 'GRAPHPAD PRISM' with 6739 mentions matched with 'PRISM' mentioned 1440 times
# 'GRAPHPAD PRISM' with 8179 mentions matched with 'GRAPH PAD PRISM' mentioned 156 times
# 'GRAPHPAD PRISM' with 8335 mentions matched with 'PRISM GRAPHPAD' mentioned 48 times
# 'GRAPHPAD PRISM' with 8383 mentions matched with 'GRAPHPAD PRISM5' mentioned 27 times
# 'GRAPHPAD PRISM' with 8410 mentions matched with 'GRAPHPAD PRISM®' mentioned 19 times
# 'GRAPHPAD PRISM' with 8429 mentions matched with 'GRAPHPAD PRIZM' mentioned 19 times
# 'GRAPHPAD PRISM' with 8448 mentions matched with 'GRAPHPAD PRISM6' mentioned 17 times
# 'GRAPHPAD PRISM' with 8465 mentions matched with 'GRAPHPADPRISM' mentioned 14 times
# 'GRAPHPAD PRISM' with 8479 mentions matched with 'GRAPHPAD PRISM7' mentioned 11 times
# 'GRAPHPAD PRISM' with 8490 mentions matched with 'GRAPHPAD PRISM8' mentioned 9 times
# 'GRAPHPAD PRISM' with 8499 mentions matched with 'GRAPPAD PRISM' mentioned 8 times
# 'EXCEL' with 4054 mentions matched with 'MS EXCEL' mentioned 155 times
# 'EXCEL' with 4209 mentions matched with 'EXCEL®' mentioned 51 times
# 'EXCEL' with 4260 mentions matched with 'OFFICE EXCEL' mentioned 28 times
# 'EXCEL' with 4288 mentions matched with 'MICROSOFT EXCEL' mentioned 20 times
# 'EXCEL' with 4308 mentions matched with 'EXCEL SOLVER' mentioned 11 times
# 'BLAST' with 3943 mentions matched with 'BLASTN' mentioned 1075 times
# 'BLAST' with 5018 mentions matched with 'BLASTP' mentioned 665 times
# 'BLAST' with 5683 mentions matched with 'BLASTX' mentioned 617 times
# 'BLAST' with 6300 mentions matched with 'BASIC LOCAL ALIGNMENT SEARCH TOOL BLAST' mentioned 148 times
# 'BLAST' with 6448 mentions matched with 'BLAT' mentioned 76 times
# 'BLAST' with 6524 mentions matched with 'LAST' mentioned 28 times
# 'BLAST' with 6552 mentions matched with 'BLAST BASIC LOCAL ALIGNMENT SEARCH TOOL' mentioned 24 times
# 'BLAST' with 6576 mentions matched with 'BASIC LOCAL ALIGNMENT SEARCH TOOL BLAST' mentioned 21 times
# 'BLAST' with 6597 mentions matched with '- BLAST' mentioned 18 times
# 'BLAST' with 6615 mentions matched with 'PBLAST' mentioned 17 times
# 'BLAST' with 6632 mentions matched with 'BLAST +' mentioned 16 times
# 'BLAST' with 6648 mentions matched with 'BLAST SEARCH' mentioned 16 times
# 'BLAST' with 6664 mentions matched with 'PRIMER BLAST' mentioned 15 times
# 'BLAST' with 6679 mentions matched with 'PROTEIN BLAST' mentioned 12 times
# 'BLAST' with 6691 mentions matched with 'NBLAST' mentioned 11 times
# 'BLAST' with 6702 mentions matched with 'NUCLEOTIDE BLAST' mentioned 9 times
# 'BLAST' with 6711 mentions matched with 'BLAST BASIC LOCAL ALIGNMENT SEARCH TOOL' mentioned 8 times
# 'STATA' with 3688 mentions matched with 'STAT' mentioned 210 times
# 'STATA' with 3898 mentions matched with 'STATA SE' mentioned 61 times
# 'STATA' with 3959 mentions matched with 'STATA MP' mentioned 38 times
# 'STATA' with 3997 mentions matched with 'STATA®' mentioned 33 times
# 'STATA' with 4030 mentions matched with 'STATA IC' mentioned 18 times
# 'SAS' with 3153 mentions matched with 'SASA' mentioned 65 times
# 'SAS' with 3218 mentions matched with 'SAS ENTERPRISE GUIDE' mentioned 41 times
# 'SAS' with 3259 mentions matched with 'SAS®' mentioned 37 times
# 'SAS' with 3296 mentions matched with 'STATISTICAL ANALYSIS SYSTEM SAS' mentioned 24 times
# 'SAS' with 3320 mentions matched with 'SAS SYSTEM' mentioned 22 times
# 'SAS' with 3342 mentions matched with 'SAS STUDIO' mentioned 16 times
# 'SAS' with 3358 mentions matched with 'SASE' mentioned 12 times
# 'SAS' with 3370 mentions matched with 'STATISTICAL ANALYSIS SYSTEM SAS' mentioned 10 times
# 'SAS' with 3380 mentions matched with 'SAS JMP' mentioned 10 times
# 'SAS' with 3390 mentions matched with 'STATISTICAL ANALYSIS SOFTWARE SAS' mentioned 9 times
# 'MATLAB' with 2653 mentions matched with 'MATLAB®' mentioned 28 times
# 'MATLAB' with 2681 mentions matched with 'MATLAB©' mentioned 10 times
# 'MATLAB' with 2691 mentions matched with 'MATLAB SCRIPT' mentioned 10 times
# 'MATLAB' with 2701 mentions matched with 'MATLAB R' mentioned 9 times
# 'GOOGLE SCHOLAR' with 2308 mentions matched with 'SCHOLAR' mentioned 64 times
# 'GOOGLE SCHOLAR' with 2372 mentions matched with 'GOOGLE' mentioned 42 times
# 'GOOGLE SCHOLAR' with 2414 mentions matched with 'GOOGLE COLAB' mentioned 26 times
# 'GOOGLE SCHOLAR' with 2440 mentions matched with 'GOOGLE®' mentioned 26 times
# 'GOOGLE SCHOLAR' with 2466 mentions matched with 'GOOGLESCHOLAR' mentioned 19 times
# 'MEGA' with 2118 mentions matched with 'MEGA6' mentioned 205 times
# 'MEGA' with 2323 mentions matched with 'MEGA7' mentioned 205 times
# 'MEGA' with 2528 mentions matched with 'MEGA X' mentioned 204 times
# 'MEGA' with 2732 mentions matched with 'MEGAN' mentioned 152 times
# 'MEGA' with 2884 mentions matched with 'MEGA5' mentioned 137 times
# 'MEGA' with 3021 mentions matched with 'MEGA4' mentioned 96 times
# 'MEGA' with 3117 mentions matched with 'OMEGA' mentioned 73 times
# 'MEGA' with 3190 mentions matched with 'MEGAX' mentioned 65 times
# 'MEGA' with 3255 mentions matched with 'MEGAM' mentioned 51 times
# 'MEGA' with 3306 mentions matched with 'MOLECULAR EVOLUTIONARY GENETICS ANALYSIS MEGA' mentioned 51 times
# 'MEGA' with 3357 mentions matched with 'MEGA3' mentioned 27 times
# 'MEGA' with 3384 mentions matched with 'MOLECULAR EVOLUTIONARY GENETICS ANALYSIS MEGA' mentioned 19 times
# 'MEGA' with 3403 mentions matched with 'MEA' mentioned 15 times
# 'MEGA' with 3418 mentions matched with 'MGA' mentioned 10 times
# 'NET' with 2041 mentions matched with 'UNET' mentioned 164 times
# 'NET' with 2205 mentions matched with '- NET' mentioned 51 times
# 'NET' with 2256 mentions matched with 'NEST' mentioned 28 times
# 'NET' with 2284 mentions matched with 'GNET' mentioned 28 times
# 'NET' with 2312 mentions matched with 'NNET' mentioned 19 times
# 'NET' with 2331 mentions matched with 'VNET' mentioned 15 times
# 'NET' with 2346 mentions matched with 'MOBILE NET' mentioned 14 times
# 'NET' with 2360 mentions matched with '. NET' mentioned 12 times
# 'NET' with 2372 mentions matched with 'NET CT' mentioned 12 times
# 'NET' with 2384 mentions matched with 'NEXT' mentioned 9 times
# 'NET' with 2393 mentions matched with 'NETS' mentioned 9 times
# 'NET' with 2402 mentions matched with 'NET CORE' mentioned 9 times
# 'NET' with 2411 mentions matched with 'ENET' mentioned 8 times
# 'NET' with 2419 mentions matched with 'NEAT' mentioned 8 times
# 'IMAGEJ' with 1949 mentions matched with 'IMAGE J' mentioned 509 times
# 'IMAGEJ' with 2458 mentions matched with 'IMAGE' mentioned 236 times
# 'IMAGEJ' with 2694 mentions matched with 'NIH IMAGEJ' mentioned 43 times
# 'IMAGEJ' with 2737 mentions matched with 'FIJI IMAGEJ' mentioned 23 times
# 'IMAGEJ' with 2760 mentions matched with 'IMAGEJ FIJI' mentioned 19 times
# 'PYTHON' with 1520 mentions matched with 'PYTHON SCRIPT' mentioned 33 times
# 'PYTHON' with 1553 mentions matched with 'PYTHON3' mentioned 19 times
# 'PYTHON' with 1572 mentions matched with 'PYTHON SCRIPTS' mentioned 15 times
# 'PYTHON' with 1587 mentions matched with 'IPYTHON' mentioned 12 times
# 'PYTHON' with 1599 mentions matched with 'PYTHON PACKAGE' mentioned 11 times
# 'PYTHON' with 1610 mentions matched with 'LEARN PYTHON' mentioned 10 times
# 'GISAID' with 1429 mentions matched with 'GISAID EPICOV' mentioned 13 times
# 'PYMOL' with 1256 mentions matched with 'PYMOL MOLECULAR GRAPHICS SYSTEM' mentioned 105 times
# 'REDCAP' with 1242 mentions matched with 'RESEARCH ELECTRONIC DATA CAPTURE REDCAP' mentioned 106 times
# 'REDCAP' with 1348 mentions matched with 'REDCAP RESEARCH ELECTRONIC DATA CAPTURE' mentioned 69 times
# 'REDCAP' with 1417 mentions matched with 'REDCAP®' mentioned 26 times
# 'REDCAP' with 1443 mentions matched with 'RECAP' mentioned 11 times
# 'REDCAP' with 1454 mentions matched with 'HREDCAP' mentioned 10 times
# 'REDCAP' with 1464 mentions matched with 'REDCAP ELECTRONIC DATA CAPTURE' mentioned 8 times
# 'REDCAP' with 1472 mentions matched with 'RESEARCH ELECTRONIC DATA CAPTURE REDCAP' mentioned 8 times
# 'GOOGLE TRENDS' with 1194 mentions matched with 'GOOGLE FLU TRENDS' mentioned 141 times
# 'GOOGLE TRENDS' with 1335 mentions matched with 'GOOGLE TREND' mentioned 49 times
# 'GOOGLE TRENDS' with 1384 mentions matched with 'GOOGLE' mentioned 42 times
# 'GOOGLE TRENDS' with 1426 mentions matched with 'TRENDS' mentioned 42 times
# 'GOOGLE TRENDS' with 1468 mentions matched with 'GOOGLE®' mentioned 26 times
# 'GOOGLE TRENDS' with 1494 mentions matched with 'GOOGLE TRENDS GT' mentioned 18 times
# 'GOOGLE TRENDS' with 1512 mentions matched with 'GOOGLE TRENDS GT' mentioned 17 times
# 'GOOGLE TRENDS' with 1529 mentions matched with 'GOOGLE FLU TRENDS GFT' mentioned 9 times
# 'GOOGLE TRENDS' with 1538 mentions matched with 'GOOGLE DENGUE TRENDS' mentioned 8 times
# 'GOOGLE TRENDS' with 1546 mentions matched with 'GOOGLE HEALTH TRENDS API' mentioned 8 times
# 'CLUSTALW' with 1104 mentions matched with 'CLUSTAL W' mentioned 385 times
# 'CLUSTALW' with 1489 mentions matched with 'CLUSTALX' mentioned 348 times
# 'CLUSTALW' with 1837 mentions matched with 'CLUSTAL' mentioned 231 times
# 'CLUSTALW' with 2068 mentions matched with 'CLUSTALW2' mentioned 78 times
# 'CLUSTALW' with 2146 mentions matched with 'CLUSTALO' mentioned 16 times
# 'FLOWJO' with 989 mentions matched with 'FLOW JO' mentioned 22 times
# 'FLOWJO' with 1011 mentions matched with 'FLOWJO STAR' mentioned 9 times
# 'FLOWJO' with 1020 mentions matched with 'FLOJO' mentioned 8 times
# 'AUTODOCK VINA' with 970 mentions matched with 'AUTODOCK' mentioned 920 times
# 'AUTODOCK VINA' with 1890 mentions matched with 'VINA' mentioned 166 times
# 'AUTODOCK VINA' with 2056 mentions matched with 'AUTODOCKVINA' mentioned 31 times
# 'AUTODOCK VINA' with 2087 mentions matched with 'AUTO DOCK VINA' mentioned 13 times
# 'BEAST' with 940 mentions matched with 'BEST' mentioned 117 times
# 'BEAST' with 1057 mentions matched with 'BEAST2' mentioned 60 times
# 'BEAST' with 1117 mentions matched with 'BREAST' mentioned 32 times
# 'BEAST' with 1149 mentions matched with 'EAST' mentioned 12 times
# 'ENSEMBL' with 800 mentions matched with 'ENSEMBLE' mentioned 167 times
# 'ENSEMBL' with 967 mentions matched with 'ENSEMBL GENOME BROWSER' mentioned 27 times
# 'ENSEMBL' with 994 mentions matched with 'ENSEMBL BIOMART' mentioned 12 times
# 'ENSEMBL' with 1006 mentions matched with 'ENSEMBL BROWSER' mentioned 12 times
# 'SKYPE' with 780 mentions matched with 'SKYPE FOR BUSINESS' mentioned 10 times
# 'BERT' with 717 mentions matched with 'MBERT' mentioned 104 times
# 'BERT' with 821 mentions matched with 'SBERT' mentioned 40 times
# 'BERT' with 861 mentions matched with 'BRT' mentioned 19 times
# 'BERT' with 880 mentions matched with '- BERT' mentioned 13 times
# 'BERT' with 893 mentions matched with 'IBERT' mentioned 10 times
# 'BERT' with 903 mentions matched with 'ERT' mentioned 9 times
# 'GENEIOUS' with 711 mentions matched with 'GENEIOUS PRIME' mentioned 100 times
# 'GENEIOUS' with 811 mentions matched with 'GENEIOUS PRO' mentioned 44 times
# 'GENEIOUS' with 855 mentions matched with 'GENEIOUS R11' mentioned 10 times
# 'GENEIOUS' with 865 mentions matched with 'GENEIOUS R10' mentioned 9 times
# 'GSEA' with 693 mentions matched with 'GENE SET ENRICHMENT ANALYSIS GSEA' mentioned 65 times
# 'GSEA' with 758 mentions matched with 'GSA' mentioned 41 times
# 'GSEA' with 799 mentions matched with 'SEA' mentioned 36 times
# 'GSEA' with 835 mentions matched with 'FGSEA' mentioned 29 times
# 'GSEA' with 864 mentions matched with 'GENE SET ENRICHMENT ANALYSIS GSEA' mentioned 13 times
# 'QUALTRICS' with 683 mentions matched with 'QUALTRICS XM' mentioned 34 times
# 'QUALTRICS' with 717 mentions matched with 'QUALTRICS SURVEY' mentioned 8 times
# 'BIOEDIT' with 658 mentions matched with 'BIOEDIT SEQUENCE ALIGNMENT EDITOR' mentioned 57 times
# 'SWISS' with 658 mentions matched with 'SWISS MODEL' mentioned 61 times
# 'SWISS' with 719 mentions matched with 'SWISS PDB VIEWER' mentioned 24 times
# 'SWISS' with 743 mentions matched with 'SWISS ADME' mentioned 11 times
# 'SWISS' with 754 mentions matched with 'SWISS TARGET PREDICTION' mentioned 9 times
# 'IOS' with 653 mentions matched with 'IGOS' mentioned 38 times
# 'IOS' with 691 mentions matched with 'DIOS' mentioned 20 times
# 'IOS' with 711 mentions matched with 'BIOS' mentioned 9 times
# 'TASSER' with 647 mentions matched with 'ITASSER' mentioned 25 times
# 'NVIVO' with 609 mentions matched with 'QSR NVIVO' mentioned 29 times
# 'NVIVO' with 638 mentions matched with 'VIVO' mentioned 16 times
# 'PHENIX' with 607 mentions matched with 'PHOENIX' mentioned 18 times
# 'PHENIX' with 625 mentions matched with 'PHENIX REFINE' mentioned 9 times
# 'COOT' with 592 mentions matched with 'COBOT' mentioned 13 times
# 'COOT' with 605 mentions matched with 'COT' mentioned 13 times
# 'LINUX' with 572 mentions matched with 'CENTOS LINUX' mentioned 10 times
# 'LINUX' with 582 mentions matched with 'LINUX KERNEL' mentioned 10 times
# 'LINUX' with 592 mentions matched with 'LINUX OS' mentioned 10 times
# 'PRISMA' with 566 mentions matched with 'PRISMA7' mentioned 9 times
# 'MODEL' with 561 mentions matched with 'SWISS MODEL' mentioned 61 times
# 'MODEL' with 622 mentions matched with 'MODE' mentioned 34 times
# 'SEURAT' with 548 mentions matched with 'R PACKAGE SEURAT' mentioned 27 times
# 'SEURAT' with 575 mentions matched with 'SEURAT R PACKAGE' mentioned 20 times
# 'SEURAT' with 595 mentions matched with 'SEURAT PACKAGE' mentioned 17 times
# 'SEURAT' with 612 mentions matched with 'SEURAT R' mentioned 13 times
# 'SIMPLOT' with 545 mentions matched with 'SIGMAPLOT' mentioned 201 times
# 'SIMPLOT' with 746 mentions matched with 'DIMPLOT' mentioned 12 times
# 'MASCOT' with 541 mentions matched with 'MASCOT SERVER' mentioned 13 times
# 'MASCOT' with 554 mentions matched with 'MASCOT DAEMON' mentioned 9 times
# 'MASCOT' with 563 mentions matched with 'MASCOT DISTILLER' mentioned 8 times
# 'SCIKIT' with 532 mentions matched with 'SCIKIT LEARN' mentioned 8 times
# 'DNASTAR' with 515 mentions matched with 'DNASTAR LASERGENE' mentioned 38 times
# 'DNASTAR' with 553 mentions matched with 'DNA STAR' mentioned 15 times
# 'CHIMERA' with 501 mentions matched with 'UCSF CHIMERA' mentioned 498 times
# 'CHIMERA' with 999 mentions matched with 'CHIMAERA' mentioned 128 times
# 'CHIMERA' with 1127 mentions matched with 'CHIMERAX' mentioned 34 times
# 'CHIMERA' with 1161 mentions matched with 'UCSF CHIMERA PACKAGE' mentioned 11 times
# 'CHIMERA' with 1172 mentions matched with 'USCF CHIMERA' mentioned 10 times
# 'CHIMERA' with 1182 mentions matched with 'CHIMERE' mentioned 8 times
# 'CLUSTAL OMEGA' with 496 mentions matched with 'CLUSTAL W' mentioned 385 times
# 'CLUSTAL OMEGA' with 881 mentions matched with 'CLUSTAL' mentioned 231 times
# 'CLUSTAL OMEGA' with 1112 mentions matched with 'CLUSTAL X' mentioned 162 times
# 'CLUSTAL OMEGA' with 1274 mentions matched with 'OMEGA' mentioned 73 times
# 'CLUSTAL OMEGA' with 1347 mentions matched with 'CLUSTAL V' mentioned 19 times
# 'CLUSTAL OMEGA' with 1366 mentions matched with 'CLUSTALOMEGA' mentioned 15 times
# 'MEDCALC' with 495 mentions matched with 'MEDCALC®' mentioned 11 times
# 'SAMTOOLS' with 493 mentions matched with 'SAMTOOLS MPILEUP' mentioned 20 times
# 'SAMTOOLS' with 513 mentions matched with 'SEMTOOLS' mentioned 10 times
# 'DESEQ2' with 492 mentions matched with 'DESEQ' mentioned 82 times
# 'DESEQ2' with 574 mentions matched with 'R PACKAGE DESEQ2' mentioned 20 times
# 'DESEQ2' with 594 mentions matched with 'DESEQ2 R' mentioned 15 times
# 'DESEQ2' with 609 mentions matched with 'DESEQ2 R PACKAGE' mentioned 9 times
# 'WINDOWS' with 492 mentions matched with 'WINDOWS XP' mentioned 29 times
# 'WINDOWS' with 521 mentions matched with 'WINDOWS 7' mentioned 12 times
# 'WINDOWS' with 533 mentions matched with 'MS WINDOWS' mentioned 11 times
# 'WINDOWS' with 544 mentions matched with 'WINDOWS SERVER' mentioned 11 times
# 'BOWTIE2' with 489 mentions matched with 'BOWTIE' mentioned 229 times
# 'BOWTIE2' with 718 mentions matched with 'BOWTIE1' mentioned 10 times
# 'LEARN' with 477 mentions matched with 'LEAN' mentioned 41 times
# 'LEARN' with 518 mentions matched with 'QLEARN' mentioned 28 times
# 'LEARN' with 546 mentions matched with 'LEARN PYTHON' mentioned 10 times
# 'LEARN' with 556 mentions matched with 'SCIKIT LEARN' mentioned 8 times
# 'GOOGLE FORMS' with 472 mentions matched with 'GOOGLE FORM' mentioned 88 times
# 'GOOGLE FORMS' with 560 mentions matched with 'GOOGLE' mentioned 42 times
# 'GOOGLE FORMS' with 602 mentions matched with 'GOOGLE®' mentioned 26 times
# 'GOOGLE FORMS' with 628 mentions matched with 'GOOGLE FORMS®' mentioned 11 times
# 'GGPLOT2' with 463 mentions matched with 'GGPLOT' mentioned 50 times
# 'GGPLOT2' with 513 mentions matched with 'R PACKAGE GGPLOT2' mentioned 23 times
# 'GGPLOT2' with 536 mentions matched with 'GGPLOT2 R' mentioned 9 times
# 'GGPLOT2' with 545 mentions matched with 'GGPLOT2 R PACKAGE' mentioned 8 times
# 'ARCGIS' with 460 mentions matched with 'ARC GIS' mentioned 20 times
# 'ARCGIS' with 480 mentions matched with 'ARCGIS PRO' mentioned 18 times
# 'ARCGIS' with 498 mentions matched with 'ARCGIS ONLINE' mentioned 14 times
# 'ARCGIS' with 512 mentions matched with 'ARCGIS DESKTOP' mentioned 13 times
# 'ARCGIS' with 525 mentions matched with 'ARCGIS10' mentioned 11 times
# 'ARCGIS' with 536 mentions matched with 'ESRI ARCGIS' mentioned 11 times
# 'CHARMM' with 454 mentions matched with 'CHARMM36' mentioned 94 times
# 'CHARMM' with 548 mentions matched with 'CHARMM27' mentioned 20 times
# 'CHARMM' with 568 mentions matched with 'CHARM' mentioned 10 times
# 'CHARMM' with 578 mentions matched with 'CHARMM22' mentioned 10 times
# 'TREE' with 452 mentions matched with 'TRE' mentioned 24 times
# 'TREE' with 476 mentions matched with 'INTERACTIVE TREE OF LIFE ITOL' mentioned 20 times
# 'TREE' with 496 mentions matched with 'TREE ANNOTATOR' mentioned 19 times
# 'TREE' with 515 mentions matched with 'TREE STAR' mentioned 17 times
# 'TREE' with 532 mentions matched with 'TEE' mentioned 15 times
# 'TREE' with 547 mentions matched with 'OTREE' mentioned 8 times
# 'TREE' with 555 mentions matched with 'IQ TREE' mentioned 8 times
# 'LASSO' with 443 mentions matched with 'GLASSO' mentioned 8 times
# 'MOE' with 429 mentions matched with 'MOEA' mentioned 124 times
# 'MOE' with 553 mentions matched with 'MOLECULAR OPERATING ENVIRONMENT MOE' mentioned 60 times
# 'MOE' with 613 mentions matched with 'MODE' mentioned 34 times
# 'MOE' with 647 mentions matched with 'MOVE' mentioned 31 times
# 'MOE' with 678 mentions matched with 'MOLECULAR OPERATING ENVIRONMENT MOE' mentioned 15 times
# 'STRING' with 428 mentions matched with 'STING' mentioned 10 times
# 'DAVID' with 421 mentions matched with 'VISUALIZATION AND INTEGRATED DISCOVERY DAVID' mentioned 27 times
# 'DAVID' with 448 mentions matched with 'DAVID BIOINFORMATICS RESOURCES' mentioned 13 times
# 'RSTUDIO' with 419 mentions matched with 'R STUDIO' mentioned 148 times
# 'RSTUDIO' with 567 mentions matched with 'STUDIO' mentioned 106 times
# 'ONE' with 416 mentions matched with 'QUANTITY ONE' mentioned 190 times
# 'ONE' with 606 mentions matched with 'CONE' mentioned 103 times
# 'ONE' with 709 mentions matched with 'ONE HEALTH' mentioned 50 times
# 'ONE' with 759 mentions matched with 'PLOS ONE' mentioned 21 times
# 'ONE' with 780 mentions matched with 'PREDICTION ONE' mentioned 12 times
# 'ONE' with 792 mentions matched with 'RAD QUANTITY ONE' mentioned 10 times
# 'ONE' with 802 mentions matched with 'ONEE' mentioned 8 times
# 'WEB' with 414 mentions matched with 'AMAZON WEB SERVICES' mentioned 31 times
# 'WEB' with 445 mentions matched with 'WEB OF SCIENCE' mentioned 17 times
# 'ROSETTA' with 406 mentions matched with 'TRROSETTA' mentioned 70 times
# 'ROSETTA' with 476 mentions matched with 'ROBETTA' mentioned 60 times
# 'ROSETTA' with 536 mentions matched with 'PYROSETTA' mentioned 25 times
# 'ROSETTA' with 561 mentions matched with 'ROSETTACM' mentioned 19 times
# 'ROSETTA' with 580 mentions matched with 'ROSETTE' mentioned 11 times
# 'AUTO' with 391 mentions matched with 'AUTO DOCK' mentioned 25 times
# 'AUTO' with 416 mentions matched with 'AUTO DOCK VINA' mentioned 13 times
# 'AUTO' with 429 mentions matched with 'AUTO DOCK TOOLS' mentioned 10 times
# 'BWA' with 386 mentions matched with 'BWA MEM' mentioned 22 times
# 'MFOLD' with 386 mentions matched with 'FOLD' mentioned 113 times
# 'NEXTSTRAIN' with 380 mentions matched with 'NEXSTRAIN' mentioned 10 times
# 'SHERLOCK' with 374 mentions matched with 'SHERLOCKV2' mentioned 12 times
# 'ADAM' with 371 mentions matched with 'ADA' mentioned 31 times
# 'ADAM' with 402 mentions matched with 'ADAM OPTIMIZER' mentioned 25 times
# 'ADAM' with 427 mentions matched with 'ADAMW' mentioned 14 times
# 'ADAM' with 441 mentions matched with 'NADAM' mentioned 8 times
# 'STAR' with 369 mentions matched with 'QUESTIONNAIRE STAR' mentioned 68 times
# 'STAR' with 437 mentions matched with 'TAR' mentioned 43 times
# 'STAR' with 480 mentions matched with 'STAR ALIGNER' mentioned 35 times
# 'STAR' with 515 mentions matched with 'STA' mentioned 22 times
# 'STAR' with 537 mentions matched with 'START' mentioned 21 times
# 'STAR' with 558 mentions matched with 'SITAR' mentioned 20 times
# 'STAR' with 578 mentions matched with 'TREE STAR' mentioned 17 times
# 'STAR' with 595 mentions matched with 'DNA STAR' mentioned 15 times
# 'STAR' with 610 mentions matched with 'ISTAR' mentioned 14 times
# 'STAR' with 624 mentions matched with 'STR' mentioned 13 times
# 'STAR' with 637 mentions matched with 'STARS' mentioned 9 times
# 'STAR' with 646 mentions matched with 'FLOWJO STAR' mentioned 9 times
# 'STAR' with 655 mentions matched with 'SETAR' mentioned 8 times
# 'HADDOCK' with 358 mentions matched with 'HADDOCK2' mentioned 10 times
# 'VMD' with 352 mentions matched with 'VISUAL MOLECULAR DYNAMICS VMD' mentioned 47 times
# 'MODELLER' with 348 mentions matched with 'MODELER' mentioned 50 times
# 'ROBERTA' with 347 mentions matched with 'ROBETTA' mentioned 60 times
# 'ROBERTA' with 407 mentions matched with 'ROBERT' mentioned 37 times
# 'ROBERTA' with 444 mentions matched with 'PROBERTA' mentioned 28 times
# 'DOCK' with 338 mentions matched with 'ZDOCK' mentioned 129 times
# 'DOCK' with 467 mentions matched with 'HDOCK' mentioned 69 times
# 'DOCK' with 536 mentions matched with 'DOC' mentioned 62 times
# 'DOCK' with 598 mentions matched with 'RDOCK' mentioned 37 times
# 'DOCK' with 635 mentions matched with 'IDOCK' mentioned 29 times
# 'DOCK' with 664 mentions matched with 'AUTO DOCK' mentioned 25 times
# 'DOCK' with 689 mentions matched with 'AUTO DOCK VINA' mentioned 13 times
# 'DOCK' with 702 mentions matched with 'DOCK3' mentioned 12 times
# 'DOCK' with 714 mentions matched with 'AUTO DOCK TOOLS' mentioned 10 times
# 'DOCK' with 724 mentions matched with 'DOCK PREP' mentioned 10 times
# 'DOCK' with 734 mentions matched with 'DOCK6' mentioned 8 times
# 'CT' with 329 mentions matched with 'SNOMED CT' mentioned 147 times
# 'CT' with 476 mentions matched with 'NET CT' mentioned 12 times
# 'SURVEYMONKEY' with 327 mentions matched with 'SURVEYMONKEY®' mentioned 30 times
# 'SURVEYMONKEY' with 357 mentions matched with 'VEYMONKEY' mentioned 9 times
# 'BEPIPRED' with 326 mentions matched with 'BEPIPRED LINEAR EPITOPE PREDICTION' mentioned 11 times
# 'BEPIPRED' with 337 mentions matched with 'BEPIPRED2' mentioned 10 times
# 'RELION' with 325 mentions matched with 'RELION3' mentioned 46 times
# 'SCIPY' with 325 mentions matched with 'SCIP' mentioned 19 times
# 'SCIPY' with 344 mentions matched with 'SCIRPY' mentioned 14 times
# 'SCIPY' with 358 mentions matched with 'SCIPY PACKAGE' mentioned 9 times
# 'COQ' with 322 mentions matched with 'ICOQ' mentioned 11 times
# 'INCEPTION' with 321 mentions matched with 'INCEPTIONV3' mentioned 120 times
# 'MS' with 320 mentions matched with 'MS EXCEL' mentioned 155 times
# 'MS' with 475 mentions matched with 'MS ACCESS' mentioned 18 times
# 'MS' with 493 mentions matched with 'MS WINDOWS' mentioned 11 times
# 'MS' with 504 mentions matched with 'MS MARCO' mentioned 10 times
# 'LIMMA' with 319 mentions matched with 'R PACKAGE LIMMA' mentioned 31 times
# 'LIMMA' with 350 mentions matched with 'LIMMA R' mentioned 24 times
# 'LIMMA' with 374 mentions matched with 'LIMMA R PACKAGE' mentioned 13 times
# 'OVID' with 317 mentions matched with 'COVID' mentioned 228 times
# 'OVID' with 545 mentions matched with 'OVID MEDLINE' mentioned 65 times
# 'OVID' with 610 mentions matched with 'NOVID' mentioned 27 times
# 'OVID' with 637 mentions matched with 'OVID EMBASE' mentioned 19 times
# 'OVID' with 656 mentions matched with '- COVID' mentioned 10 times
# 'OVID' with 666 mentions matched with 'OVI' mentioned 9 times
# 'MTURK' with 310 mentions matched with 'TURK' mentioned 18 times
# 'MTURK' with 328 mentions matched with 'MECHANICAL TURK MTURK' mentioned 12 times
# 'BIOCONDUCTOR' with 306 mentions matched with 'BIOCONDUCTOR PACKAGE' mentioned 31 times
# 'BIOCONDUCTOR' with 337 mentions matched with 'R BIOCONDUCTOR' mentioned 14 times
# 'EPIC' with 305 mentions matched with 'EPI' mentioned 227 times
# 'EPIC' with 532 mentions matched with 'PIC' mentioned 26 times
# 'EPIC' with 558 mentions matched with 'EPIC©' mentioned 13 times
# 'EPIC' with 571 mentions matched with 'EPIC MYCHART' mentioned 11 times
# 'EPIC' with 582 mentions matched with 'EPIC SYSTEMS' mentioned 9 times
# 'SQL' with 303 mentions matched with 'SQL SERVER' mentioned 24 times
# 'SQL' with 327 mentions matched with 'SPARK SQL' mentioned 18 times
# 'SQL' with 345 mentions matched with 'ADVANCED SQL' mentioned 9 times
# 'POWER' with 301 mentions matched with 'GPOWER' mentioned 31 times
# 'POWER' with 332 mentions matched with 'MPOWER' mentioned 16 times
# 'POWER' with 348 mentions matched with 'G POWER' mentioned 14 times
# 'KERAS' with 299 mentions matched with 'ERAS' mentioned 22 times
# 'KERAS' with 321 mentions matched with 'KERAS IMAGEDATAGENERATOR' mentioned 8 times
# 'BIO' with 299 mentions matched with 'BIOC' mentioned 21 times
# 'BIO' with 320 mentions matched with 'BIGO' mentioned 19 times
# 'BIO' with 339 mentions matched with 'CLC BIO' mentioned 16 times
# 'BIO' with 355 mentions matched with 'MBIO' mentioned 13 times
# 'BIO' with 368 mentions matched with 'BIOS' mentioned 9 times
# 'HEALTHMAP' with 296 mentions matched with 'HEATMAP' mentioned 11 times
# 'IQ' with 293 mentions matched with 'IQ TREE' mentioned 8 times
# 'CAM' with 293 mentions matched with 'SCAM' mentioned 23 times
# 'CAM' with 316 mentions matched with 'CALM' mentioned 19 times
# 'CAM' with 335 mentions matched with 'GCAM' mentioned 17 times
# 'CAM' with 352 mentions matched with 'CAMS' mentioned 16 times
# 'CAM' with 368 mentions matched with 'CAMM' mentioned 9 times
# 'MAESTRO' with 289 mentions matched with 'SCHRÖDINGER MAESTRO' mentioned 15 times
# 'NETMHCPAN' with 288 mentions matched with 'NETMHCIIPAN' mentioned 108 times
# 'NETMHCPAN' with 396 mentions matched with 'NETMHCPAN4' mentioned 65 times
# 'NETMHCPAN' with 461 mentions matched with 'NETMHCPAN EL' mentioned 9 times
# 'PREDICT' with 286 mentions matched with 'PREDICTA' mentioned 14 times
# 'PREDICT' with 300 mentions matched with '19PREDICT' mentioned 10 times
# 'PREDICT' with 310 mentions matched with 'PREDICTRV' mentioned 9 times
# 'PREDICT' with 319 mentions matched with 'PREDICTIV' mentioned 8 times
# 'DISCOVERY STUDIO' with 286 mentions matched with 'R STUDIO' mentioned 148 times
# 'DISCOVERY STUDIO' with 434 mentions matched with 'DISCOVERY' mentioned 132 times
# 'DISCOVERY STUDIO' with 566 mentions matched with 'STUDIO' mentioned 106 times
# 'DISCOVERY STUDIO' with 672 mentions matched with 'DISCOVERY STUDIO VISUALIZER' mentioned 98 times
# 'DISCOVERY STUDIO' with 770 mentions matched with 'BIOVIA DISCOVERY STUDIO' mentioned 46 times
# 'DISCOVERY STUDIO' with 816 mentions matched with 'BIOVIA DISCOVERY STUDIO VISUALIZER' mentioned 31 times
# 'DISCOVERY STUDIO' with 847 mentions matched with 'ACCELRYS DISCOVERY STUDIO' mentioned 22 times
# 'DISCOVERY STUDIO' with 869 mentions matched with 'DISCOVERYSTUDIO' mentioned 12 times
# 'DISCOVERY STUDIO' with 881 mentions matched with 'DISCOVERY STUDIO DS' mentioned 8 times
# 'TMHMM' with 285 mentions matched with 'TMHMM SERVER' mentioned 20 times
# 'TMHMM' with 305 mentions matched with 'TMHMM2' mentioned 14 times
# 'SMART' with 285 mentions matched with 'SMART PLS' mentioned 31 times
# 'SMART' with 316 mentions matched with 'SMART RECOVERY' mentioned 19 times
# 'SMART' with 335 mentions matched with 'MART' mentioned 14 times
# 'SMART' with 349 mentions matched with 'SMARTS' mentioned 13 times
# 'SMART' with 362 mentions matched with 'SMRT' mentioned 13 times
# 'SMART' with 375 mentions matched with 'SMART VACCINES' mentioned 12 times
# 'SMART' with 387 mentions matched with 'SMART POOLING' mentioned 8 times
# 'REVIEW MANAGER' with 284 mentions matched with 'REVIEW MANAGER REVMAN' mentioned 31 times
# 'REVIEW MANAGER' with 315 mentions matched with 'REVIEW' mentioned 12 times
# 'REVIEW MANAGER' with 327 mentions matched with 'COCHRANE REVIEW MANAGER' mentioned 10 times
# 'REVIEW MANAGER' with 337 mentions matched with 'REVIEW MANAGER REVMAN' mentioned 10 times
# 'WIKIDATA' with 283 mentions matched with 'WIKIDATA PROPERTYSUGGESTER' mentioned 8 times
# 'TRACETOGETHER' with 281 mentions matched with 'ABTRACETOGETHER' mentioned 13 times
# 'TRACETOGETHER' with 294 mentions matched with 'TRACETOGETHER APP' mentioned 8 times
# 'STATISTICA' with 280 mentions matched with 'STATISTA' mentioned 108 times
# 'STATISTICA' with 388 mentions matched with 'STATISTICS' mentioned 18 times
# 'STATISTICA' with 406 mentions matched with 'STATISTICAL' mentioned 12 times
# 'UMAP' with 280 mentions matched with 'MAP' mentioned 90 times
# 'UMAP' with 370 mentions matched with '- MAP' mentioned 8 times
# 'FASTQC' with 279 mentions matched with 'FASTQ' mentioned 142 times
# 'TRACER' with 273 mentions matched with 'TRACE' mentioned 69 times
# 'TRACER' with 342 mentions matched with 'TRACERX' mentioned 22 times
# 'TRACER' with 364 mentions matched with 'TRACKER' mentioned 13 times
# 'EPIESTIM' with 268 mentions matched with 'R PACKAGE EPIESTIM' mentioned 21 times
# 'EPIESTIM' with 289 mentions matched with 'EPIESTIM R' mentioned 12 times
# 'GOOGLE MAPS' with 263 mentions matched with 'GOOGLE' mentioned 42 times
# 'GOOGLE MAPS' with 305 mentions matched with 'GOOGLE MAP' mentioned 36 times
# 'GOOGLE MAPS' with 341 mentions matched with 'MAPS' mentioned 34 times
# 'GOOGLE MAPS' with 375 mentions matched with 'GOOGLE®' mentioned 26 times
# 'GOOGLE MAPS' with 401 mentions matched with 'GOOGLE MAPS API' mentioned 22 times
# 'GOOGLE MAPS' with 423 mentions matched with 'GOOGLE API' mentioned 14 times
# 'ELMO' with 262 mentions matched with 'ELM' mentioned 96 times
# 'FIJI' with 262 mentions matched with 'FIJI IMAGEJ' mentioned 23 times
# 'FIJI' with 285 mentions matched with 'IMAGEJ FIJI' mentioned 19 times
# 'IPA' with 260 mentions matched with 'INGENUITY PATHWAY ANALYSIS IPA' mentioned 89 times
# 'IPA' with 349 mentions matched with 'IPAT' mentioned 31 times
# 'IPA' with 380 mentions matched with 'INGENUITY PATHWAY ANALYSIS IPA' mentioned 23 times
# 'IPA' with 403 mentions matched with 'INGENUITY PATHWAYS ANALYSIS IPA' mentioned 21 times
# 'IPA' with 424 mentions matched with 'IPAC' mentioned 21 times
# 'IPA' with 445 mentions matched with 'IPMA' mentioned 11 times
# 'PSI' with 257 mentions matched with 'PSOI' mentioned 12 times
# 'SE' with 257 mentions matched with 'STATA SE' mentioned 61 times
# 'GLOVE' with 256 mentions matched with 'LOVE' mentioned 16 times
# 'GALAXY' with 256 mentions matched with 'GALAXY REFINE' mentioned 27 times
# 'GALAXY' with 283 mentions matched with 'GALAXY ZOO' mentioned 10 times
# 'REVMAN' with 254 mentions matched with 'REVIEW MANAGER REVMAN' mentioned 31 times
# 'REVMAN' with 285 mentions matched with 'REVMAN5' mentioned 22 times
# 'REVMAN' with 307 mentions matched with 'REVIEW MANAGER REVMAN' mentioned 10 times
# 'EDGER' with 254 mentions matched with 'EDGE' mentioned 43 times
# 'EDGER' with 297 mentions matched with 'R PACKAGE EDGER' mentioned 16 times
# 'EDGER' with 313 mentions matched with 'EDGER PACKAGE' mentioned 9 times
# 'EDGER' with 322 mentions matched with 'EDGER R PACKAGE' mentioned 9 times
# 'GRAD' with 253 mentions matched with 'GRADE' mentioned 165 times
# 'GRAD' with 418 mentions matched with 'RAD' mentioned 29 times
# 'GRAD' with 447 mentions matched with 'GRA' mentioned 19 times
# 'GRAD' with 466 mentions matched with 'GRAND' mentioned 11 times
# 'JMP' with 252 mentions matched with 'JMP PRO' mentioned 52 times
# 'JMP' with 304 mentions matched with 'JUMP' mentioned 12 times
# 'JMP' with 316 mentions matched with 'JMP®' mentioned 10 times
# 'JMP' with 326 mentions matched with 'SAS JMP' mentioned 10 times
# 'JMP' with 336 mentions matched with 'JMP GENOMICS' mentioned 9 times
# 'GPT' with 250 mentions matched with 'GPT2' mentioned 9 times
# 'IDSEQ' with 249 mentions matched with 'IDSEQ NT' mentioned 14 times
# 'PAUP' with 244 mentions matched with 'PAUP *' mentioned 11 times
# 'ENRICHR' with 244 mentions matched with 'ENRICH' mentioned 15 times
# 'ENRICHR' with 259 mentions matched with 'ENRICHER' mentioned 10 times
# 'EMBASE' with 243 mentions matched with 'OVID EMBASE' mentioned 19 times
# 'CLC GENOMICS WORKBENCH' with 242 mentions matched with 'CLC' mentioned 48 times
# 'CLC GENOMICS WORKBENCH' with 290 mentions matched with 'CLC GENOMIC WORKBENCH' mentioned 39 times
# 'CLC GENOMICS WORKBENCH' with 329 mentions matched with 'WORKBENCH' mentioned 17 times
# 'CLC GENOMICS WORKBENCH' with 346 mentions matched with 'CLC WORKBENCH' mentioned 17 times
# 'CLC GENOMICS WORKBENCH' with 363 mentions matched with 'CLC GENOMICS' mentioned 15 times
# 'MPI' with 241 mentions matched with 'OPEN MPI' mentioned 20 times
# 'MPI' with 261 mentions matched with 'MPI ALLREDUCE' mentioned 10 times
# 'FIGTREE' with 239 mentions matched with 'BIGTREE' mentioned 9 times
# 'PUBMED' with 239 mentions matched with 'PUBMED CENTRAL' mentioned 24 times
# 'ENDNOTE' with 239 mentions matched with 'ENDNOTE X9' mentioned 48 times
# 'ENDNOTE' with 287 mentions matched with 'ENDNOTE X8' mentioned 18 times
# 'ENDNOTE' with 305 mentions matched with 'ENDNOTE X7' mentioned 17 times
# 'ENDNOTE' with 322 mentions matched with 'ENDNOTEX9' mentioned 11 times
# 'PHYLIP' with 237 mentions matched with 'PHYLIP PACKAGE' mentioned 16 times
# 'MICROSOFT TEAMS' with 233 mentions matched with 'TEAMS' mentioned 37 times
# 'MICROSOFT TEAMS' with 270 mentions matched with 'MICROSOFT' mentioned 16 times
# 'SPADES' with 232 mentions matched with 'SPADE' mentioned 34 times
# 'SPADES' with 266 mentions matched with 'SPADES ASSEMBLER' mentioned 14 times
# 'IDEA' with 232 mentions matched with 'IDEAS' mentioned 48 times
# 'IDEA' with 280 mentions matched with 'DEA' mentioned 17 times
# 'IDEA' with 297 mentions matched with 'IDA' mentioned 14 times
# 'IDEA' with 311 mentions matched with 'IDEAL' mentioned 12 times
# 'IDEA' with 323 mentions matched with 'INTELLIJ IDEA' mentioned 11 times
# 'COV' with 232 mentions matched with 'NCOV' mentioned 64 times
# 'COV' with 296 mentions matched with 'COVI' mentioned 34 times
# 'COV' with 330 mentions matched with 'CONV' mentioned 25 times
# 'COV' with 355 mentions matched with 'COVE' mentioned 16 times
# 'UBER' with 231 mentions matched with 'UBER EATS' mentioned 37 times
# 'CNN' with 229 mentions matched with 'MASK R - CNN' mentioned 71 times
# 'CNN' with 300 mentions matched with 'RCNN' mentioned 25 times
# 'CNN' with 325 mentions matched with 'CONN' mentioned 23 times
# 'CNN' with 348 mentions matched with 'FASTER R - CNN' mentioned 22 times
# 'CNN' with 370 mentions matched with 'CANN' mentioned 14 times
# 'CNN' with 384 mentions matched with 'MASK R CNN' mentioned 11 times
# 'CNN' with 395 mentions matched with '- CNN' mentioned 9 times
# 'CNN' with 404 mentions matched with 'CASCADE R - CNN' mentioned 8 times
# 'CNN' with 412 mentions matched with 'CGNN' mentioned 8 times
# 'SPARK' with 227 mentions matched with 'APACHE SPARK' mentioned 82 times
# 'SPARK' with 309 mentions matched with 'SPARKY' mentioned 28 times
# 'SPARK' with 337 mentions matched with 'SPARKS' mentioned 21 times
# 'SPARK' with 358 mentions matched with 'SPARK SQL' mentioned 18 times
# 'SPARK' with 376 mentions matched with 'SPARK NLP' mentioned 14 times
# 'SPARK' with 390 mentions matched with 'SPAR' mentioned 12 times
# 'META' with 225 mentions matched with 'COMPREHENSIVE META - ANALYSIS' mentioned 68 times
# 'META' with 293 mentions matched with 'METAL' mentioned 18 times
# 'META' with 311 mentions matched with 'RAY META' mentioned 15 times
# 'META' with 326 mentions matched with 'MEA' mentioned 15 times
# 'META' with 341 mentions matched with 'R PACKAGE META' mentioned 9 times
# 'META' with 350 mentions matched with 'METAN' mentioned 9 times
# 'META' with 359 mentions matched with 'MET' mentioned 8 times
# 'META' with 367 mentions matched with 'ETA' mentioned 8 times
# 'RDP' with 225 mentions matched with 'RDP4' mentioned 145 times
# 'RDP' with 370 mentions matched with 'RDP3' mentioned 33 times
# 'RDP' with 403 mentions matched with 'RECOMBINATION DETECTION PROGRAM RDP' mentioned 23 times
# 'RDP' with 426 mentions matched with 'RDP5' mentioned 13 times
# 'RDP' with 439 mentions matched with 'RECOMBINATION DETECTION PROGRAM RDP' mentioned 12 times
# 'RDP' with 451 mentions matched with 'RDRP' mentioned 10 times
# 'RDP' with 461 mentions matched with 'RDP2' mentioned 10 times
# 'SIM' with 225 mentions matched with 'VSIM' mentioned 53 times
# 'SIM' with 278 mentions matched with 'SLIM' mentioned 33 times
# 'SIM' with 311 mentions matched with 'SWIM' mentioned 22 times
# 'SIM' with 333 mentions matched with 'SVIM' mentioned 18 times
# 'SIM' with 351 mentions matched with 'SIMM' mentioned 12 times
# 'SIM' with 363 mentions matched with 'SIRM' mentioned 11 times
# 'SIM' with 374 mentions matched with 'SIMR' mentioned 9 times
# 'SIM' with 383 mentions matched with 'SIMV' mentioned 9 times
# 'SIM' with 392 mentions matched with 'ESIM' mentioned 8 times
# 'COCHRANE' with 223 mentions matched with 'COCHRANE RISK OF BIAS TOOL' mentioned 22 times
# 'COCHRANE' with 245 mentions matched with 'COCHRANE ROB' mentioned 21 times
# 'COCHRANE' with 266 mentions matched with 'COCHRANE RISK OF BIAS' mentioned 17 times
# 'COCHRANE' with 283 mentions matched with 'COCHRANE COLLABORATION' mentioned 12 times
# 'COCHRANE' with 295 mentions matched with 'COCHRANE LIBRARY' mentioned 11 times
# 'COCHRANE' with 306 mentions matched with 'COCHRANE REVIEW MANAGER' mentioned 10 times
# 'COCHRANE' with 316 mentions matched with 'COCHRANE RISK' mentioned 9 times
# 'COCHRANE' with 325 mentions matched with 'COCHRANE HANDBOOK' mentioned 9 times
# 'AI' with 222 mentions matched with '. AI' mentioned 8 times
# 'AI' with 230 mentions matched with 'GOOGLE AI' mentioned 8 times
# 'MINIMAP2' with 221 mentions matched with 'MINIMAP' mentioned 11 times
# 'WEBEX' with 221 mentions matched with 'CISCO WEBEX' mentioned 54 times
# 'PROTPARAM' with 220 mentions matched with 'EXPASY PROTPARAM' mentioned 30 times
# 'PRO' with 220 mentions matched with 'PRO PLUS' mentioned 114 times
# 'PRO' with 334 mentions matched with 'PROB' mentioned 109 times
# 'PRO' with 443 mentions matched with 'PROC' mentioned 93 times
# 'PRO' with 536 mentions matched with 'FILEMAKER PRO' mentioned 75 times
# 'PRO' with 611 mentions matched with 'GENEPIX PRO' mentioned 54 times
# 'PRO' with 665 mentions matched with 'JMP PRO' mentioned 52 times
# 'PRO' with 717 mentions matched with 'CELLQUEST PRO' mentioned 47 times
# 'PRO' with 764 mentions matched with 'IMAGE PRO PLUS' mentioned 46 times
# 'PRO' with 810 mentions matched with 'PROT' mentioned 45 times
# 'PRO' with 855 mentions matched with 'SOFTMAX PRO' mentioned 45 times
# 'PRO' with 900 mentions matched with 'MPRO' mentioned 44 times
# 'PRO' with 944 mentions matched with 'GENEIOUS PRO' mentioned 44 times
# 'PRO' with 988 mentions matched with 'ORIGIN PRO' mentioned 30 times
# 'PRO' with 1018 mentions matched with 'PROP' mentioned 29 times
# 'PRO' with 1047 mentions matched with 'SEQMAN PRO' mentioned 22 times
# 'PRO' with 1069 mentions matched with 'TREEAGE PRO' mentioned 21 times
# 'PRO' with 1090 mentions matched with 'PROQ' mentioned 20 times
# 'PRO' with 1110 mentions matched with 'IGOR PRO' mentioned 19 times
# 'PRO' with 1129 mentions matched with 'ARCGIS PRO' mentioned 18 times
# 'PRO' with 1147 mentions matched with 'PROM' mentioned 17 times
# 'PRO' with 1164 mentions matched with 'IMAGE PRO - PLUS' mentioned 14 times
# 'PRO' with 1178 mentions matched with 'QUANTASOFT ANALYSIS PRO' mentioned 14 times
# 'PRO' with 1192 mentions matched with 'IMAGE PRO' mentioned 13 times
# 'PRO' with 1205 mentions matched with 'NODEXL PRO' mentioned 12 times
# 'PRO' with 1217 mentions matched with 'CRYSALIS PRO' mentioned 11 times
# 'PRO' with 1228 mentions matched with 'PERO' mentioned 11 times
# 'PRO' with 1239 mentions matched with 'PIRO' mentioned 10 times
# 'PRO' with 1249 mentions matched with 'CELL QUEST PRO' mentioned 9 times
# 'PRO' with 1258 mentions matched with 'BD CELLQUEST PRO' mentioned 8 times
# ...
# 'GLFORTHEL' with 15 mentions matched with 'FORTHEL' mentioned 9 times
# 'DIST' with 15 mentions matched with 'DIS' mentioned 14 times
# 'DIST' with 29 mentions matched with 'DISTS' mentioned 12 times
# 'PHYLODYNAMIC' with 14 mentions matched with 'PHYLODYNAMICS' mentioned 12 times
# 'PEACE' with 14 mentions matched with 'PACE' mentioned 13 times
# 'LOLAS' with 14 mentions matched with 'LOLA' mentioned 10 times
# 'SSPS' with 14 mentions matched with 'SSP' mentioned 10 times
# 'VEGAS' with 14 mentions matched with 'VGAS' mentioned 10 times
# 'ACTILIFE' with 14 mentions matched with 'ACTLIFE' mentioned 10 times
# 'DATAWARRIOR' with 14 mentions matched with 'OSIRIS DATAWARRIOR' mentioned 9 times
# 'SIG' with 14 mentions matched with 'SIGA' mentioned 11 times
# 'STATA16' with 14 mentions matched with 'STATA14' mentioned 12 times
# 'STATA16' with 26 mentions matched with 'STATA15' mentioned 10 times
# 'STATA16' with 36 mentions matched with 'STATA12' mentioned 9 times
# 'POZE' with 14 mentions matched with 'POZ' mentioned 8 times
# 'PLA' with 14 mentions matched with 'PLSA' mentioned 13 times
# 'PLA' with 27 mentions matched with 'PLAY' mentioned 11 times
# 'IPHONE' with 14 mentions matched with 'PHONE' mentioned 10 times
# 'SIN' with 14 mentions matched with 'SINA' mentioned 11 times
# 'TACE' with 14 mentions matched with 'TAC' mentioned 13 times
# 'SCHR€' with 14 mentions matched with 'SCR' mentioned 8 times
# 'POPPER' with 14 mentions matched with 'POPPER HELPER' mentioned 8 times
# 'MEPS' with 14 mentions matched with 'MES' mentioned 8 times
# 'NVAC' with 14 mentions matched with 'VAC' mentioned 8 times
# 'COSIL' with 14 mentions matched with 'COSI' mentioned 8 times
# 'SNPNEXUS COVID' with 14 mentions matched with '- COVID' mentioned 10 times
# 'ERAN' with 14 mentions matched with 'RAN' mentioned 12 times
# 'ERAN' with 26 mentions matched with 'ERN' mentioned 10 times
# 'GLCM' with 14 mentions matched with 'GLM' mentioned 9 times
# 'SEIRS' with 14 mentions matched with 'SEIRUS' mentioned 10 times
# 'PAICE' with 14 mentions matched with 'PACE' mentioned 13 times
# 'MMT' with 14 mentions matched with 'MMAT' mentioned 13 times
# 'MMT' with 27 mentions matched with 'MMTC' mentioned 10 times
# 'LOAT' with 14 mentions matched with 'LOT' mentioned 12 times
# 'KEYMAERA X' with 14 mentions matched with 'KEYMAERA' mentioned 12 times
# 'NHSX' with 14 mentions matched with 'NHS' mentioned 8 times
# 'VISE' with 14 mentions matched with 'VISNE' mentioned 12 times
# 'SOSCI SURVEY' with 14 mentions matched with 'SOSCISURVEY' mentioned 10 times
# 'ICAT' with 14 mentions matched with 'ICA' mentioned 11 times
# 'ICAT' with 25 mentions matched with 'CICAT' mentioned 8 times
# 'BREASTSCREEN' with 14 mentions matched with 'RETSCREEN' mentioned 12 times
# 'IGSA' with 14 mentions matched with 'ISA' mentioned 8 times
# 'MARCH' with 14 mentions matched with 'ARCH' mentioned 13 times
# 'MARCH' with 27 mentions matched with 'MACH' mentioned 9 times
# 'CLEM' with 14 mentions matched with 'CLTEM' mentioned 11 times
# 'CLEM' with 25 mentions matched with 'CLE' mentioned 9 times
# 'RNN' with 14 mentions matched with 'RGNN' mentioned 9 times
# 'ORCCA' with 14 mentions matched with 'ORCA' mentioned 10 times
# 'HYDE' with 14 mentions matched with 'HYDEN' mentioned 11 times
# 'CDGL' with 14 mentions matched with 'DGL' mentioned 10 times
# 'CDGL' with 24 mentions matched with 'CGL' mentioned 9 times
# 'SED' with 14 mentions matched with 'SEED' mentioned 13 times
# 'SYN' with 14 mentions matched with 'SYNC' mentioned 10 times
# 'CMSEARCH' with 14 mentions matched with '- SEARCH' mentioned 10 times
# 'EAVE' with 14 mentions matched with 'AVE' mentioned 9 times
# 'ICODEHOP' with 14 mentions matched with 'CODEHOP' mentioned 11 times
# 'DAGAN' with 14 mentions matched with 'DAWGAN' mentioned 13 times
# 'MEHT' with 13 mentions matched with 'MET' mentioned 8 times
# 'AEGIS' with 13 mentions matched with 'AEIS' mentioned 9 times
# 'MELT' with 13 mentions matched with 'MET' mentioned 8 times
# 'GENOMESTUDIO' with 13 mentions matched with 'ILLUMINA GENOMESTUDIO' mentioned 10 times
# 'BOSSL' with 13 mentions matched with 'BOSS' mentioned 13 times
# 'FACTT' with 13 mentions matched with '- FACT' mentioned 11 times
# 'SPARSE' with 13 mentions matched with 'PARSE' mentioned 11 times
# 'SPARSE' with 24 mentions matched with 'CUSPARSE' mentioned 11 times
# 'SUBREAD' with 13 mentions matched with 'RSUBREAD' mentioned 13 times
# 'QUBIT' with 13 mentions matched with 'QUIT' mentioned 11 times
# 'IRD' with 13 mentions matched with 'MIRD' mentioned 12 times
# 'IRD' with 25 mentions matched with 'BIRD' mentioned 8 times
# 'DYSM' with 13 mentions matched with 'DYS' mentioned 8 times
# 'CROWN' with 13 mentions matched with 'CROW' mentioned 11 times
# 'PEC' with 13 mentions matched with 'APEC' mentioned 8 times
# 'GEOMX DSP' with 13 mentions matched with 'GEOMX' mentioned 9 times
# 'MPLOC' with 13 mentions matched with 'PLOC' mentioned 9 times
# 'TEN' with 13 mentions matched with 'CTEN' mentioned 8 times
# 'CNTK' with 13 mentions matched with 'CNT' mentioned 12 times
# 'MIXED METHODS APPRAISAL TOOL MMAT' with 13 mentions matched with 'TOOL' mentioned 11 times
# 'ESPEN' with 13 mentions matched with 'ESPN' mentioned 9 times
# 'CONNECTIVITY MAP' with 13 mentions matched with 'CONNECTIVITY MAP CMAP' mentioned 10 times
# 'CONNECTIVITY MAP' with 23 mentions matched with 'CONNECTIVITY MAP CMAP' mentioned 9 times
# 'CONNECTIVITY MAP' with 32 mentions matched with '- MAP' mentioned 8 times
# 'HFS' with 13 mentions matched with 'HDFS' mentioned 10 times
# 'GRAPHDTA' with 13 mentions matched with 'GRAPHDNA' mentioned 12 times
# 'MARVIN' with 13 mentions matched with 'MARVIN SKETCH' mentioned 10 times
# 'MASTER' with 13 mentions matched with 'IMAGE MASTER 2D PLATINUM' mentioned 9 times
# 'GENET' with 13 mentions matched with 'GELNET' mentioned 12 times
# 'GENET' with 25 mentions matched with 'ENET' mentioned 8 times
# 'DEEPFM' with 13 mentions matched with 'XDEEPFM' mentioned 8 times
# '2D' with 13 mentions matched with 'IMAGE MASTER 2D PLATINUM' mentioned 9 times
# 'RTWEET' with 13 mentions matched with 'TWEET' mentioned 10 times
# 'PMA' with 13 mentions matched with 'IPMA' mentioned 11 times
# 'ORIGO' with 13 mentions matched with 'ORIG' mentioned 8 times
# 'INS' with 13 mentions matched with 'RINS' mentioned 11 times
# 'PATHOCHIP' with 13 mentions matched with 'PATHCHIP' mentioned 8 times
# 'BIOSAMPLE' with 13 mentions matched with 'BIOSAMPLER' mentioned 10 times
# 'LIBGUIDE' with 13 mentions matched with 'LIBGUIDES' mentioned 8 times
# 'KIDS' with 13 mentions matched with 'GOCHECK KIDS' mentioned 11 times
# 'ABSREL' with 13 mentions matched with 'BSREL' mentioned 10 times
# 'ENALOS' with 13 mentions matched with 'ENALOS INSILICO' mentioned 9 times
# 'REUS' with 13 mentions matched with 'REMUS' mentioned 8 times
# 'CONVKB' with 12 mentions matched with 'PCONVKB' mentioned 12 times
# 'GYM' with 12 mentions matched with 'ROBUSTNESS GYM' mentioned 10 times
# 'IMPUTE' with 12 mentions matched with 'IMPUTE2' mentioned 9 times
# 'WASF' with 12 mentions matched with 'ASF' mentioned 8 times
# 'SCAR' with 12 mentions matched with 'OSCAR' mentioned 11 times
# 'SCAR' with 23 mentions matched with 'SCR' mentioned 8 times
# 'ARIES' with 12 mentions matched with 'ARIS' mentioned 11 times
# 'FEAST' with 12 mentions matched with 'EAST' mentioned 12 times
# 'EMIND' with 12 mentions matched with 'MIND' mentioned 10 times
# 'LUCA' with 12 mentions matched with 'LUA' mentioned 11 times
# 'VIA' with 12 mentions matched with 'VITA' mentioned 11 times
# 'VIA' with 23 mentions matched with 'VIVA' mentioned 11 times
# 'VIA' with 34 mentions matched with 'VISA' mentioned 10 times
# 'VIA' with 44 mentions matched with 'VIAP' mentioned 8 times
# 'ULTIMATE AUTOMIZER' with 12 mentions matched with 'ULTIMATE' mentioned 11 times
# 'GLIDESCOPE' with 12 mentions matched with 'GLIDESCORE' mentioned 8 times
# 'ALIX' with 12 mentions matched with 'ALI' mentioned 11 times
# 'VAMS' with 12 mentions matched with 'VAM' mentioned 9 times
# 'REGA' with 12 mentions matched with 'REG' mentioned 10 times
# 'STEP' with 12 mentions matched with 'VERSO STEP' mentioned 10 times
# 'STEP' with 22 mentions matched with 'STEEP' mentioned 10 times
# 'EDEM' with 12 mentions matched with 'EDE' mentioned 8 times
# 'SEQUENCE DETECTOR' with 12 mentions matched with 'SEQUENCE DETECTION' mentioned 8 times
# 'INTERNET' with 12 mentions matched with 'INTERVET' mentioned 9 times
# 'INTERNET' with 21 mentions matched with 'INTERNET ARCHIVE' mentioned 8 times
# 'GOA' with 12 mentions matched with 'GOAP' mentioned 10 times
# 'GOA' with 22 mentions matched with 'GOEA' mentioned 9 times
# 'EVM' with 12 mentions matched with 'KEVM' mentioned 9 times
# 'MRT' with 12 mentions matched with 'IMRT' mentioned 9 times
# 'NAIVE' with 12 mentions matched with 'NATIVE' mentioned 11 times
# 'SIMVA' with 12 mentions matched with 'SIMV' mentioned 9 times
# 'IFCN' with 12 mentions matched with 'FCN' mentioned 9 times
# 'SCIMAT' with 12 mentions matched with 'SCIMATH' mentioned 10 times
# 'PENN' with 12 mentions matched with 'PEN' mentioned 8 times
# 'IMR' with 12 mentions matched with 'SIMR' mentioned 9 times
# 'IMR' with 21 mentions matched with 'IMRT' mentioned 9 times
# 'SPLUS' with 12 mentions matched with 'SPLS' mentioned 10 times
# 'IDSA' with 12 mentions matched with 'ISA' mentioned 8 times
# 'LEAD' with 11 mentions matched with 'LAD' mentioned 9 times
# 'STRATUS' with 11 mentions matched with 'STRATOS' mentioned 11 times
# 'TC2S' with 11 mentions matched with 'TCS' mentioned 11 times
# 'APO' with 11 mentions matched with 'SAPO' mentioned 9 times
# 'REML' with 11 mentions matched with 'REM' mentioned 11 times
# 'REML' with 22 mentions matched with 'RML' mentioned 9 times
# 'TENET' with 11 mentions matched with 'ENET' mentioned 8 times
# 'PIKES' with 11 mentions matched with 'PIES' mentioned 11 times
# 'TETHER' with 11 mentions matched with 'TOGETHER' mentioned 10 times
# 'DIGITALMICROGRAPH' with 11 mentions matched with 'DIGITAL MICROGRAPH' mentioned 8 times
# 'WEGO' with 11 mentions matched with 'EGO' mentioned 8 times
# 'TCGA' with 11 mentions matched with 'TCA' mentioned 10 times
# 'COVIDCODES' with 11 mentions matched with 'COVIDCODE' mentioned 9 times
# 'GLYCAN READER & MODELER' with 11 mentions matched with 'GLYCAN READER' mentioned 10 times
# 'GECS' with 11 mentions matched with 'GCS' mentioned 10 times
# 'NAAT' with 11 mentions matched with 'NAT' mentioned 11 times
# 'DCA' with 11 mentions matched with 'DCAT' mentioned 8 times
# 'MEMSAT' with 11 mentions matched with 'MEMSAT3' mentioned 8 times
# 'TREESCAN' with 11 mentions matched with 'RESCAN' mentioned 11 times
# 'PROCTOR' with 11 mentions matched with 'PROCTORIO' mentioned 8 times
# 'CORVID' with 11 mentions matched with '- COVID' mentioned 10 times
# 'DAPA' with 11 mentions matched with 'DAP' mentioned 10 times
# 'ACADEMIC SEARCH COMPLETE' with 11 mentions matched with '- SEARCH' mentioned 10 times
# 'ACADEMIC SEARCH COMPLETE' with 21 mentions matched with 'ACADEMIC' mentioned 8 times
# 'ULTRA' with 11 mentions matched with 'COLLABORATE ULTRA' mentioned 11 times
# 'ULTRA' with 22 mentions matched with 'XPERT ULTRA' mentioned 10 times
# 'ULTRA' with 32 mentions matched with 'CHEMDRAW ULTRA' mentioned 8 times
# 'CMALIGN' with 11 mentions matched with 'TMALIGN' mentioned 10 times
# 'MDR' with 11 mentions matched with 'MDRA' mentioned 11 times
# 'CHOICE' with 11 mentions matched with 'HOICE' mentioned 8 times
# 'MOSAE' with 11 mentions matched with 'MOSA' mentioned 8 times
# 'PLIER' with 11 mentions matched with 'PLIERS' mentioned 8 times
# 'SYNCT' with 11 mentions matched with 'SYNC' mentioned 10 times
# 'TPP' with 11 mentions matched with 'TPP SYSTMONE' mentioned 8 times
# 'INSILICO' with 11 mentions matched with 'ENALOS INSILICO' mentioned 9 times
# 'CMCM' with 11 mentions matched with 'CCM' mentioned 10 times
# 'CMCM' with 21 mentions matched with 'MCM' mentioned 8 times
# 'ELPI' with 11 mentions matched with 'ELI' mentioned 8 times
# 'EMAS' with 11 mentions matched with 'EMS' mentioned 10 times
# 'MOCA' with 11 mentions matched with 'MOCHA' mentioned 8 times
# 'CLARIOMD' with 11 mentions matched with 'CLARIOMS' mentioned 10 times
# 'PRISM8' with 11 mentions matched with 'GRAPHPAD PRISM8' mentioned 9 times
# 'GOOGLE COVID' with 11 mentions matched with '- COVID' mentioned 10 times
# 'NEMS' with 11 mentions matched with 'EMS' mentioned 10 times
# 'TWISTER' with 10 mentions matched with 'TWITTER' mentioned 9 times
# 'ICOPE MONITOR' with 10 mentions matched with 'ICOPE' mentioned 9 times
# 'ITEA' with 10 mentions matched with 'ITE' mentioned 8 times
# 'ITEA' with 18 mentions matched with 'TEA' mentioned 8 times
# 'PLUMX' with 10 mentions matched with 'PLUM' mentioned 9 times
# 'DATASET SEARCH' with 10 mentions matched with '- SEARCH' mentioned 10 times
# 'MOG' with 10 mentions matched with 'SMOG' mentioned 8 times
# 'NPI' with 10 mentions matched with 'INPI' mentioned 9 times
# 'MCRM' with 10 mentions matched with 'MCM' mentioned 8 times
# 'DIDI' with 10 mentions matched with 'DID' mentioned 9 times
# 'RTLS' with 10 mentions matched with 'RLS' mentioned 9 times
# 'CLINPRO TOOLS' with 10 mentions matched with 'CLINPROTOOLS' mentioned 9 times
# 'MMR' with 10 mentions matched with 'MMRF' mentioned 8 times
# 'ASEAN' with 10 mentions matched with 'ASEA' mentioned 9 times
# 'OGLASSO' with 10 mentions matched with 'GLASSO' mentioned 8 times
# 'AMAP' with 10 mentions matched with 'ABMAP' mentioned 9 times
# 'AMAP' with 19 mentions matched with '- MAP' mentioned 8 times
# 'GOOGLE SURVEYS' with 10 mentions matched with 'GOOGLE SURVEY' mentioned 9 times
# 'COMBN' with 10 mentions matched with 'COMB' mentioned 9 times
# 'PATHCHECK' with 10 mentions matched with 'PATHCHECK SAFEPLACES' mentioned 9 times
# 'LLA' with 10 mentions matched with 'LOLA' mentioned 10 times
# 'GLOBPLOT' with 10 mentions matched with 'GOPLOT' mentioned 8 times
# 'VOS VIEWER' with 10 mentions matched with 'VIEWER' mentioned 9 times
# 'XT' with 10 mentions matched with 'ETHOVISION XT' mentioned 9 times
# 'LATEM' with 10 mentions matched with 'LATE' mentioned 8 times
# 'SBS' with 10 mentions matched with 'SBVS' mentioned 9 times
# 'TWITTER ANALYTICS' with 10 mentions matched with 'TWITTER' mentioned 9 times
# 'PRISM7' with 10 mentions matched with 'PRISMA7' mentioned 9 times
# 'RISA' with 10 mentions matched with 'ISA' mentioned 8 times
# 'REGRNA2' with 9 mentions matched with 'REGRNA' mentioned 9 times
# 'TWITTER CHATS' with 9 mentions matched with 'TWITTER' mentioned 9 times
# 'RIP' with 9 mentions matched with 'RJIP' mentioned 9 times
# 'PHEG' with 9 mentions matched with 'HEG' mentioned 9 times
# 'RADX' with 9 mentions matched with 'ADX' mentioned 9 times
# 'MAAP' with 9 mentions matched with '- MAP' mentioned 8 times
# 'ETE' with 9 mentions matched with 'ETE3' mentioned 9 times
# 'MLA' with 9 mentions matched with 'MMLA' mentioned 9 times
# 'GAMA' with 9 mentions matched with 'GAA' mentioned 8 times
# 'AMBER20' with 9 mentions matched with 'AMBER10' mentioned 9 times
# 'NOS' with 9 mentions matched with 'NEOS' mentioned 8 times
# 'RCDK' with 9 mentions matched with 'CDK' mentioned 8 times
# 'KVM' with 9 mentions matched with 'KEVM' mentioned 9 times
# 'VECSCREEN' with 9 mentions matched with 'ECOSCREEN' mentioned 9 times
# 'MATRIXDB' with 9 mentions matched with 'MATRIX' mentioned 9 times
# 'CHEMMINER' with 9 mentions matched with 'CHEMMINE' mentioned 9 times
# 'SEQUENCE DETECTION SYSTEM' with 9 mentions matched with 'SEQUENCE DETECTION' mentioned 8 times
# 'GAAS' with 9 mentions matched with 'GAA' mentioned 8 times
# 'GSMR' with 9 mentions matched with 'GMR' mentioned 8 times
# 'CEXPRESSION' with 9 mentions matched with 'SNEXPRESSION' mentioned 8 times
# 'CESP' with 9 mentions matched with 'CSP' mentioned 8 times
# 'EXPANDER' with 9 mentions matched with 'EXPAND' mentioned 8 times
# 'IMRPHENOMPV2' with 9 mentions matched with 'IMRPHENOMPV3HM' mentioned 8 times
# 'SOS' with 8 mentions matched with 'SOXS' mentioned 8 times
# 'COMMONS' with 8 mentions matched with 'PATHWAY COMMONS' mentioned 8 times
# 'IMPLAN' with 8 mentions matched with 'IPLAN' mentioned 8 times
# 'GMAA' with 8 mentions matched with 'GAA' mentioned 8 times
# 'GADV' with 8 mentions matched with 'ADV' mentioned 8 times
# 'CUSP' with 8 mentions matched with 'CSP' mentioned 8 times
# Wall time: 1h 35min 48s

# %% [markdown]
# The blacklist contains the matched duplicates which means that they need to be removed from the dataframe.

# %%
for i in blacklist:
    name_of_index = df_unified[ df_unified['Software'] == i ].index
    df_unified.drop(name_of_index, inplace = True)

# %% [markdown]
# For comparison purposes, the DataFrame is sorted in descending order by matches.

# %%
df_unified.sort_values(by=['Matches'], inplace=True, ascending=False)
df_unified
# Out:
#             Software  Matches
# 0                  R    13187
# 1               SPSS    11322
# 2     GRAPHPAD PRISM     8507
# 4              BLAST     6719
# 3              EXCEL     4319
# ...              ...      ...
# 9571        GROWTREE        8
# 9570             KIT        8
# 9569         POLYJET        8
# 9567          ARCHS4        8
# 9998   TOUSANTICOVID        8
#
# [7610 rows x 2 columns]

# %% [markdown]
# To verify the removal of duplicates, the length of the dataframe is outputed.

# %%
len(df_unified)
# Out:
# 7610

# %% [markdown]
# To investigate the postion change of software mentions, the following algorithm compares its index postion to the sorted postion by matches.

# %%
list_change = []
for i in range(len(df_unified)):
    dif = df_unified.index[i]-i
    if(dif > 0):
        list_change.append("+"+str(dif))
    else:
        list_change.append(df_unified.index[i]-i)
df_unified['Change'] = list_change
df_unified.head(50)
# Out:
#                                         Software  Matches Change
# 0                                              R    13187      0
# 1                                           SPSS    11322      0
# 2                                 GRAPHPAD PRISM     8507      0
# 4                                          BLAST     6719     +1
# 3                                          EXCEL     4319     -1
# 5                                          STATA     4048      0
# 10                                          MEGA     3428     +4
# 6                                            SAS     3399     -1
# 12                                        IMAGEJ     2779     +4
# 7                                         MATLAB     2710     -2
# 8                                 GOOGLE SCHOLAR     2485     -2
# 11                                           NET     2427      0
# 21                                      CLUSTALW     2162     +9
# 24                                 AUTODOCK VINA     2100    +11
# 13                                        SCOPUS     1845     -1
# 14                                        PYTHON     1620     -1
# 20                                 GOOGLE TRENDS     1554     +4
# 18                                        REDCAP     1480     +1
# 16                                        GISAID     1442     -2
# 60                                 CLUSTAL OMEGA     1381    +41
# 17                                         PYMOL     1361     -3
# 219                                          PRO     1282   +198
# 58                                       CHIMERA     1190    +36
# 26                                         BEAST     1161     +3
# 23                                        FLOWJO     1028     -1
# 31                                       ENSEMBL     1018     +6
# 25                                         MAFFT      948     -1
# 27                                     CYTOSCAPE      931      0
# 33                                          BERT      912     +5
# 144                             DISCOVERY STUDIO      889   +115
# 29                                       XGBOOST      879     -1
# 35                                          GSEA      877     +4
# 34                                      GENEIOUS      874     +2
# 253                                       PRIMER      866   +220
# 30                                       GROMACS      834     -4
# 673                                     ANALYSIS      812   +638
# 85                                           ONE      810    +49
# 32                                         SKYPE      790     -5
# 379  STATISTICAL PACKAGE FOR THE SOCIAL SCIENCES      777   +341
# 40                                         SWISS      763     +1
# 52                                       SIMPLOT      758    +12
# 107                                         DOCK      742    +66
# 66                                       BOWTIE2      728    +24
# 37                                     QUALTRICS      725     -6
# 41                                           IOS      720     -3
# 39                                       BIOEDIT      715     -6
# 80                                           MOE      693    +34
# 36                                        MUSCLE      684    -11
# 119                                         OVID      675    +71
# 83                                       RSTUDIO      673    +34

# %% [markdown]
# Assigning the outcome of this notebook to a new dataframe for the classification notebook.
# The outcome is stored on an external file.

# %%
df_software_mentions = df_unified
df_software_mentions.to_pickle('software_mentions_CS5099.pkl')
